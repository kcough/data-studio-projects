# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/kaitlincough/Documents/data_studio_projects_2017/data-studio-projects/code/cruise_ships/cruise_ship_deficiency.csv')

# %%
df.head(20)
# Out:
#                     cruise_line       cruise_ship  deficiency_item_number  \
# 0   Carnival Cruise Lines, Inc.  Carnival Fantasy                      10
# 1   Carnival Cruise Lines, Inc.  Carnival Fantasy                      26
# 2   Carnival Cruise Lines, Inc.  Carnival Fantasy                      26
# 3   Carnival Cruise Lines, Inc.  Carnival Fantasy                      26
# 4   Carnival Cruise Lines, Inc.  Carnival Fantasy                      35
# 5   Carnival Cruise Lines, Inc.  Carnival Fantasy                      38
# 6   Carnival Cruise Lines, Inc.  Carnival Fantasy                      38
# 7   Carnival Cruise Lines, Inc.  Carnival Fantasy                      39
# 8   Carnival Cruise Lines, Inc.  Carnival Fantasy                      39
# 9   Carnival Cruise Lines, Inc.  Carnival Fantasy                      41
# 10         Seabourn Cruise Line   Seabourn Spirit                      21
# 11         Seabourn Cruise Line   Seabourn Spirit                      21
# ...

# %%
df.inspection_date.value_counts(ascending=True)
# Out:
# 10/20/1994     1
# 09/20/1994     1
# 04/04/1992     1
# 06/16/1995     1
# 08/13/2001     1
# 12/16/1993     1
# 06/15/1995     1
# 02/13/1998     2
# 03/05/1997     2
# 03/05/2001     2
# 02/15/1995     2
# 08/27/1995     2
# 10/02/2002     2
# 04/28/2003     2
# 09/11/2002     2
# 02/20/2005     2
# 06/17/1998     2
# 08/29/1993     3
# 09/29/1995     3
# 02/07/2002     3
# 10/22/1995     3
# 12/29/1997     3
# 03/06/1990     3
# 04/04/2004     3
# 10/19/2000     3
# 01/13/1996     3
# 10/09/1994     3
# 05/19/1996     3
# 12/22/1996     3
# 10/20/2002     4
#               ..
# 12/20/2004    65
# 11/20/2004    66
# 11/19/2004    67
# 07/15/2005    68
# 08/22/1999    69
# 12/22/2003    70
# 11/20/2002    70
# 07/22/2004    70
# 04/30/2005    70
# 04/05/2005    71
# 04/27/2001    71
# 12/07/2005    72
# 12/17/2000    72
# 02/09/2003    72
# 05/14/2005    72
# 07/15/2002    74
# 12/05/2004    74
# 03/09/2003    74
# 11/17/2001    77
# 12/21/2003    78
# 12/18/2004    79
# ...

# %%
df.cruise_ship.value_counts().head()
# Out:
# Carnival Fantasy        874
# Carnival Sensation      692
# Carnival Ecstasy        678
# Carnival Sunshine       663
# Carnival Fascination    655
# Name: cruise_ship, dtype: int64

# %%
df.inspection_score.describe()
# Out:
# count    25480.000000
# mean        93.116680
# std          5.631062
# min         36.000000
# 25%         91.000000
# 50%         94.000000
# 75%         97.000000
# max        100.000000
# Name: inspection_score, dtype: float64

# %%
#36 is crazy low. what ship is that??
df.loc[df['inspection_score'] == 36]
# Out:
#                             cruise_line  cruise_ship  deficiency_item_number  \
# 2813  Mitsui O.S.K. Passenger Line, Ltd  Nippon Maru                      10
# 2814  Mitsui O.S.K. Passenger Line, Ltd  Nippon Maru                      11
# 2815  Mitsui O.S.K. Passenger Line, Ltd  Nippon Maru                      11
# 2816  Mitsui O.S.K. Passenger Line, Ltd  Nippon Maru                      11
# 2817  Mitsui O.S.K. Passenger Line, Ltd  Nippon Maru                      12
# 2818  Mitsui O.S.K. Passenger Line, Ltd  Nippon Maru                      13
# 2819  Mitsui O.S.K. Passenger Line, Ltd  Nippon Maru                      14
# 2820  Mitsui O.S.K. Passenger Line, Ltd  Nippon Maru                      14
# 2821  Mitsui O.S.K. Passenger Line, Ltd  Nippon Maru                      14
# 2822  Mitsui O.S.K. Passenger Line, Ltd  Nippon Maru                      15
# 2823  Mitsui O.S.K. Passenger Line, Ltd  Nippon Maru                      15
# ...
