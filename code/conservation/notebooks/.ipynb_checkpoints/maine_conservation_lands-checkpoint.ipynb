# %% [markdown]
# ## Write your headlines first
# ## practice your two line pitch
# ## then write subheaders & sketch out story

# %% [markdown]
# ## List of databases I'm working with:
#
# #### megis_one : #from here: http://www.maine.gov/megis/catalog/ downloaded shapefile
# ...after speaking to someone at MCHT realized that it was missing info.
#
# Contacted Bob Bistrais at MEGIS bob.bistrais@maine.gov who sent over the new, unpublished file,
# which I called
#
# #### megis_two

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import pysal as ps
import requests
from bs4 import BeautifulSoup
# from selenium import webdriver
# driver = webdriver.Chrome()

# %matplotlib inline

# %% [markdown]
# ## MEGIS
# (#from here: http://www.maine.gov/megis/catalog/) has a shapefile of Conserved Lands in Maine. Let's look at it.
#
#
# Data Dictionary info that's relevant:
#
#
#     ACQ_YEAR: acquisition year
#     CALC_AC : calculated acreage
#     DESIGNATIO : designation (easement, sanctuary, etc.)
#     HOLD1_NAME : manager
#     HOLD1_TYPE : state/private
#     PARCEL_NAM : name of the preserve/parcel/easement
#     geometry : polygon = shape of holding

# %%
#from here: http://www.maine.gov/megis/catalog/
megis_one = gpd.read_file('/Users/kaitlincough/Documents/data_studio/big_files_that_make_github_sad/shapefiles/conserved_landss/conserved_lands.shp')

# %%
pd.set_option("display.max_columns", 100)
megis_one.head(100)
# Out:
#       ACQ_DATE ACQ_YEAR    BPL_ID      CALC_AC  CL_UNIQUEI CONS1_TYPE  \
# 0         None                       26.857197         787
# 1         None     1965               8.314696           1        Fee
# 2         None                       52.293330           2        Fee
# 3   1993-12-27     1993             247.049757           3        Fee
# 4         None     2001               1.816991           4   Easement
# 5         None     2001               0.084249           5   Easement
# 6   1989-09-06     1989              30.675615           6   Easement
# 7         None     2001               0.025927           7   Easement
# 8         None     2001               0.063186           8   Easement
# 9         None     2001               0.535307           9   Easement
# 10        None     2001               3.298554          10   Easement
# 11  1978-12-14     1978  10058477   441.460611          11        Fee
# 12  1994-10-26     1994               3.671756          12        Fee
# 13  1983-11-23     1983               1.749503          13        Fee
# 14  2004-08-09     2004               1.513481          14        Fee
# 15  1992-05-22     1992    55-630    10.754847          15        Fee
# 16  1992-09-25     1992               3.877666          16   Easement
# 17        None       NA               0.892672          17        Fee
# 18        None     2001            5003.422326          18   Easement
# 19        None                       17.836289          19        Fee
# 20  1982-01-25     1982              54.388838          20        Fee
# 21  1985-08-30     1985              11.514119          21        Fee
# 22        None     2001              40.246433          22   Easement
# 23        None     2001             132.514116          23   Easement
# 24  1978-12-14     1978  10057966    18.543607          24   Easement
# 25  1983-03-30     1983    63-314     0.495011          25        Fee
# 26  1981-12-30     1981  10006508     0.011261          26        Fee
# 27  2002-03-27     2002             362.018217          27        Fee
# 28        None                        0.371181          28        Fee
# 29        None                        2.528227          29        Fee
# ..         ...      ...       ...          ...         ...        ...
# 70  1988-09-02     1988               8.646293          70        Fee
# 71        None     2002             753.317573          71        Fee
# 72  1989-03-21     1989  10003520     3.555714          72   Easement
# 73  1988-10-06     1988  10054102     2.859325          73        Fee
# 74  1989-03-21     1989  10003520     1.767126          74   Easement
# 75  1978-03-31     1978    79-488     3.466555          75        Fee
# 76  1961-11-10     1961              11.404130          76        Fee
# 77        None                       45.522799          77        Fee
# 78  1992-12-18     1992    79-422     2.888932          78        Fee
# 79  2003-12-23     2003             765.408615          79   Easement
# 80        None     1969    59-001     0.986736          80        Fee
# 81        None             59-439    89.787686          81        Fee
# 82        None                        6.945049          82        Fee
# 83  1983-05-26     1983    63-402     8.854086          83        Fee
# 84  1968-12-18     1968              18.156768          84        Fee
# 85        None             63-107     0.174652          85        Fee
# 86        None                       16.252146          86        Fee
# 87        None                        7.935753          87        Fee
# 88  1967-03-21     1967    63-126    10.045301          88        Fee
# 89        None             65-316     0.940488          89        Fee
# 90  2003-12-23     2003             139.496513          90   Easement
# 91        None     2003               8.351057          91   Easement
# 92  1989-10-04     1989              36.748735          92   Easement
# 93  1978-12-14     1978  10022855     5.547545          93   Easement
# 94        None                      157.611158          94        Fee
# 95        None                      432.674044          95        Fee
# 96        None             65-165   302.100906          96        Fee
# 97  1990-08-03     1990             158.741810          97        Fee
# 98        None                        9.591708          98        Fee
# 99        None             65-201     7.906623          99        Fee
#
#            CONS2_TYPE   DEPT_ID                             DESIGNATIO  \
# 0
# 1                                Nature Preserve / Reserve / Sanctuary
# 2
# 3                                Nature Preserve / Reserve / Sanctuary
# 4
# 5
# 6                                                Conservation Easement
# 7
# 8
# 9
# 10
# 11                     10058477  Nature Preserve / Reserve / Sanctuary
# 12
# 13                               Nature Preserve / Reserve / Sanctuary
# 14
# 15                Fee                   State Wildlife Management Area
# 16                                               Conservation Easement
# 17                                            National Wildlife Refuge
# 18
# 19
# 20           Easement            Nature Preserve / Reserve / Sanctuary
# 21                               Nature Preserve / Reserve / Sanctuary
# 22  Easement Enforcer                                         Easement
# 23
# 24                     10057966             Private Conservation Lands
# 25                                                      Coastal Island
# 26           Easement  10006508               National Wildlife Refuge
# 27
# 28                                          Private Conservation Lands
# 29                                          Private Conservation Lands
# ..                ...       ...                                    ...
# 70                                      State Wildlife Management Area
# 71
# 72                     10003520             Private Conservation Lands
# 73                     10054102  Nature Preserve / Reserve / Sanctuary
# 74                     10003520             Private Conservation Lands
# 75                                      State Wildlife Management Area
# 76                               Nature Preserve / Reserve / Sanctuary
# 77
# 78                                      State Wildlife Management Area
# 79                                               Conservation Easement
# 80                                                      Coastal Island
# 81                                                      Coastal Island
# 82
# 83                                      State Wildlife Management Area
# 84                               Nature Preserve / Reserve / Sanctuary
# 85                                                      Coastal Island
# 86
# 87                                            National Wildlife Refuge
# 88                               Nature Preserve / Reserve / Sanctuary
# 89                                                      Coastal Island
# 90                                               Conservation Easement
# 91                                               Conservation Easement
# 92                                               Conservation Easement
# 93                     10022855             Private Conservation Lands
# 94
# 95                                                   National Cemetery
# 96                                                      Coastal Island
# 97                               Nature Preserve / Reserve / Sanctuary
# 98
# 99                                                      Coastal Island
#
#    ECO_RESERV           EDITOR  \
# 0
# 1                Ellen Jackson
# 2
# 3                Ellen Jackson
# 4
# 5
# 6                  Chris Cabot
# 7
# 8
# 9
# 10
# 11               Ellen Jackson
# 12              Gwen Kozlowski
# 13               Ellen Jackson
# 14                Janet Parker
# 15              Gwen Kozlowski
# 16                 Chris Cabot
# 17               Ellen Jackson
# 18             Justin Schlawin
# 19
# 20               Ellen Jackson
# 21               Ellen Jackson
# 22               Ellen Jackson
# 23             Justin Schlawin
# 24               Ellen Jackson
# 25             Devon Witherell
# 26               Ellen Jackson
# 27                Janet Parker
# 28
# 29
# ..        ...              ...
# 70                 Chris Cabot
# 71
# 72               Ellen Jackson
# 73               Ellen Jackson
# 74               Ellen Jackson
# 75             Devon Witherell
# 76               Ellen Jackson
# 77
# 78             Devon Witherell
# 79
# 80                Erik Walling
# 81             Devon Witherell
# 82
# 83             Devon Witherell
# 84               Ellen Jackson
# 85             Devon Witherell
# 86
# 87              Gwen Kozlowski
# 88               Ellen Jackson
# 89             Devon Witherell
# 90
# 91
# 92                 Chris Cabot
# 93               Ellen Jackson
# 94
# 95
# 96             Devon Witherell
# 97               Ellen Jackson
# 98
# 99             Devon Witherell
#
#                                              FMPROCSS    FMUPDDAT GAP_STATUS  \
# 0                                                            None
# 1                                                            None          2
# 2                                                            None          4
# 3                                                            None          1
# 4                                                            None          3
# 5                                                            None          3
# 6   put-copies selected features, coordinate infor...  2009-07-16          3
# 7                                                            None          3
# 8                                                            None          3
# 9                                                            None          3
# 10                                                           None          3
# 11                                                           None          1
# 12  put-copies selected features, coordinate infor...  2010-04-07          3
# 13                                                           None          1
# 14  copy-duplicates features and INFO files to a n...  2009-07-28          3
# 15  put-copies selected features, coordinate infor...  2010-09-30          3
# 16  dig-digitizes or converts spatial features on ...  2009-08-18          3
# 17  copy-duplicates features and INFO files to a n...  2009-10-29          2
# 18  copy-duplicates features and INFO files to a n...  2015-01-08          3
# 19                                                           None          4
# 20  put-copies selected features, coordinate infor...  2009-08-10          1
# 21                                                           None          1
# 22  copy-duplicates features and INFO files to a n...  2013-11-04          3
# 23  copy-duplicates features and INFO files to a n...  2015-01-08          3
# 24                                                           None          3
# 25  put-copies selected features, coordinate infor...  2010-09-15          3
# 26  put-copies selected features, coordinate infor...        None          2
# 27                                                     2009-08-06          1
# 28                                                           None          3
# 29                                                           None          3
# ..                                                ...         ...        ...
# 70  screendig-feature was drawn using a mouse and ...  2009-10-21          3
# 71                                                           None          2
# 72                                                           None          3
# 73                                                           None          1
# 74                                                           None          3
# 75  put-copies selected features, coordinate infor...  2010-09-13          3
# 76                                                           None          1
# 77                                                           None          3
# 78  put-copies selected features, coordinate infor...  2010-09-13          3
# 79                                                           None          3
# 80  put-copies selected features, coordinate infor...  2010-09-09          3
# 81  put-copies selected features, coordinate infor...  2010-10-01          2
# 82                                                           None          4
# 83  put-copies selected features, coordinate infor...  2010-09-15          3
# 84                                                           None          1
# 85  put-copies selected features, coordinate infor...  2010-05-10          2
# 86                                                           None          4
# 87  put-copies selected features, coordinate infor...  2010-01-25          2
# 88                                                     2010-05-04          1
# 89  put-copies selected features, coordinate infor...  2010-05-12          3
# 90                                                           None          3
# 91                                                           None          3
# 92  put-copies selected features, coordinate infor...  2009-07-28          3
# 93                                                           None          3
# 94                                                           None          2
# 95                                                           None          4
# 96  put-copies selected features, coordinate infor...  2010-05-12          2
# 97  dig-digitizes or converts spatial features on ...  2005-08-03          1
\
# 0
# 1
# 2
# 3
# 4
# 5
# 6                                                                 0013001
# 7
# 8
# 9
# 10
# 11
# 12                                                                0641002
# 13
# 14
# 15                                                                0357001
# 16                                                                0024003
# 17
# 18
# 19
# 20  Maine Department of Inland Fisheries and Wildlife      State  0773001
# 21
# 22  New Hampshire Complex Systems Research Center-...    Private
# 23
# 24
# 25                                                                0188001
# 26                             The Nature Conservancy    Private
# 27
# 28
# 29
# ..                                                ...        ...      ...
# 70                                                                0330001
# 71
# 72
# 73
# 74
# 75                                                                0050001
# 76
# 77
# 78                                                                0022001
# 79
# 80                                                                0143001
# 81
# 82
# 83                                                                0172001
# 84
# 85
# 86
# 87
# 88
# 89                                                                0219001
# 90
# 91
# 92                                                                0646001
# 93
# 94
# 95
# 96
# 97
# 98
# 99
#
#    IUCN_STATU    LMF_ID                                              NOTE_  \
# 0
# 1                                                    MEFO File Survey; CAP
# 2                                                       Roadside Rest Area
# 3                                                         MEFO File Survey
# 4
# 5
# 6                        Digitized boundaries from georeferenced 1973 s...
# 7
# 8
# 9
# 10
# 11                                      MEFO File Map - survey on 24K; CAP
# 12             10124000                  Updated attributes from IFW files
# 13                                                                  Survey
# 14             20406000  copy from parcel layer;-NHD lines fitted 4/16/...
# 15                    1  Updated attributes from IFW files. Added BPL I...
# 16                       Digitized boundaries from georeferenced 1992 s...
# 17
# 18                       Changed geometry with new data from NEFF - elj...
# 19                                                      Roadside Rest Area
# 20                       MEFO File Survey, MEGIS metwp24p and streams -...
# 21                                                           MEFO File Map
# 22                                               shapefile recd from Hold2
# 23                       Changed geometry with new data from NEFF - elj...
# 24                                    composite survey on 24K - MEFO files
# 25                       Verified by SubmergedLands-BPL-DKW. Updated at...
# 26
# 27             10107000              original shape, updated project name;
# 28             10421000                        attribute update 4/21/16 LH
# 29             10421000                        attribute update 4/21/16 LH
# ..        ...       ...                                                ...
# 70                       Digitized from same survey as Slefkin; attribu...
# 71             10108000
# 72                                                                USGS 24K
# 73                                                                USGS 24K
# 74                                                                USGS 24K
# 75                       Updated attributes only. Added BPL ID (EAW). I...
# 76                                Survey October 1961, Black and White DOQ
# 77
# 78                       Copied from metwp24p boundaries. Updated attri...
# 79             10209000
# 80                       attribute update, added IFW ID and BPL CIR, ac...
# 81                       Verified by SubmergedLands-BPL-DKW. Updated at...
# 82                                                 Roadside Rest Area; CAP
# 83                         Updated attributes only.DW. Added BPL ID (EAW).
# 84                                                          24K Coast Data
# 85                       Verified by SubmergedLands-BPL-DKW. Updated at...
# 86                                                 Roadside Rest Area; CAP
# 87
# 88                       MEGIS metwp24p shapefile; Verified by Submerge...
# 89                       Verified by SubmergedLands-BPL-DKW. Updated at...
# 90             10209000
# 91             10209000
# 92                        Updated attributes only from MDIFW files 7/28/09
# 93                                    composite survey on 24K - MEFO files
# 94                                                                     CAP
# 95
# 96                       Verified by SubmergedLands-BPL-DKW. Updated at...
# 97                                                            survey / doq
# 98                                                      Roadside Rest Area
# 99                       Verified by SubmergedLands-BPL-DKW. Updated at...
#
#                            PARCEL_NAM  \
# 0
# 1
# 2                            ASH HILL
# 3
# 4                    PINGREE EASEMENT
# 5                    PINGREE EASEMENT
# 6                   McBurnie Property
# 7                    PINGREE EASEMENT
# 8                    PINGREE EASEMENT
# 9                    PINGREE EASEMENT
# 10                   PINGREE EASEMENT
# 11
# 12                            Islands
# 13
# 14                        Indian Lake
# 15                        Mark Island
# 16                           Parcel C
# 17                          Tract 21a
# 18                            Pingree
# 19                  GANTNIERS LANDING
# 20
# 21
# 22                            Pingree
# 23                            Pingree
# 24
# 25                        Goose Rocks
# 26                         Tract 200h
# 27                             COOPER
# 28
# 29
# ..                                ...
# 70                           Bradford
# 71                         EAST RIDGE
# 72
# 73
# 74
# 75                     Farnsworth Lot
# 76
# 77                           BACK BAY
# 78                 Inner Goose Island
# 79                      Machias River
# 80                       Spirit Ledge
# 81                 Little Duck Island
# 82                          CLAM COVE
# 83
# 84
# 85
# 86                       SHERMAN LAKE
# 87                          Tract 209
# 88                       Smith Island
# 89                   Inner Duck Rocks
# 90                      Machias River
# 91                      Machias River
# 92
# 93
# 94
# 95  US NATL. CEMETERY (Togus Med. C.)
# 96                         Hog Island
# 97
# 98                 ANDROSCOGGIN RIVER
# 99                   Western Egg Rock
#
#                                               PROJECT  \
# 0
# 1                                   La Verna Preserve
# 2                                ASH HILL SCENIC AREA
# 3                                 Saco Heath Preserve
# 4                                    PINGREE EASEMENT
# 5                                    PINGREE EASEMENT
# 6                                        Conant Brook
# 7                                    PINGREE EASEMENT
# 8                                    PINGREE EASEMENT
# 9                                    PINGREE EASEMENT
# 10                                   PINGREE EASEMENT
# 11                         Great Wass Island Preserve
# 12                                       Spednic Lake
# 13                            Larrabee Heath Preserve
# 14                                        Indian Lake
# 15                                  Outer Mark Island
# 16                                   West Lake Access
# 17                 Moosehorn National Wildlife Refuge
# 18                                            Pingree
# 19                      GANTNIERS LANDING SCENIC AREA
# 20                                        Hersey Cove
# 21                            Larrabee Heath Preserve
# 22                                            Pingree
# 23                                            Pingree
# 24                Great Wass Island Easements (Pres.)
# 25                                        Goose Rocks
# 26               Petit Manan National Wildlife Refuge
# 27                                       Dennys River
# 28                                Katahdin Iron Works
# 29                                Katahdin Iron Works
# ..                                                ...
# 70                             Alonzo H. Garcelon WMA
# 71                                         EAST RIDGE
# 72  Great Wass Island Archipelago, Cows Yard Easement
# 73          GWI, INNER AND OUTER MAN ISLANDS PRESERVE
# 74  Great Wass Island Archipelago, Cows Yard Easement
# 75                                     Ballast Island
# 76                                Step Falls Preserve
# 77                                           BACK BAY
# 78                                 Inner Goose Island
# 79                              MACHIAS RIVER Phase I
# 80                                       Spirit Ledge
# 81                                 Little Duck Island
# 82                              CLAM COVE SCENIC AREA
# 83                                   Fisherman Island
# 84          Big Garden and Big White Islands Preserve
# 85
# 86                           Sherman Lake Picnic Area
# 87               Petit Manan National Wildlife Refuge
# 88                              Smith Island Preserve
# 89                                   Inner Duck Rocks
# 90                              MACHIAS RIVER Phase I
# 91                              MACHIAS RIVER Phase I
# 92                             Scott Liberty Easement
# 93                Great Wass Island Easements (Pres.)
# 94                             Mast Landing Sanctuary
# 95                  US NATL. CEMETERY (Togus Med. C.)
# 96                                         Hog Island
# 97                                Perham Bog Preserve
# 98                     ANDROSCOGGIN RIVER SCENIC AREA
# 99                                   Western Egg Rock
#
#                                            PUB_ACCESS  \
# 0        Contact landowner for additional information
# 1   Allowed for general uses, contact owner for de...
# 2        Contact landowner for additional information
# 3        Contact landowner for additional information
# 4        Contact landowner for additional information
# 5        Contact landowner for additional information
# 6        Contact landowner for additional information
# 7        Contact landowner for additional information
# 8        Contact landowner for additional information
# 73  POLYGON ((617782.7496999996 4927451.500299999,...
# 74  POLYGON ((616923.0628000004 4928339.000299999,...
# 75  POLYGON ((614887.0619999999 4935143.4998, 6148...
# 76  POLYGON ((351447.4123 4936980.4081, 351443.058...
# 77  POLYGON ((587921.1874000002 4933827.0001, 5881...
# 78  POLYGON ((605791.6870999997 4931121.999700001,...
# 79  POLYGON ((587566.4380999999 4980096.0001, 5874...
# 80  POLYGON ((538178.9375 4881878.5, 538188.750400...
# 81  POLYGON ((560164.1251999997 4891277.5002, 5601...
# 82  POLYGON ((492725.2187000001 4887299.9998, 4928...
# 83  POLYGON ((496921.9999000002 4876427.500700001,...
# 84  POLYGON ((507173.2495999997 4876853.4998, 5072...
# 85  POLYGON ((510497.5313999997 4880559.5001, 5105...
# 86  POLYGON ((452585.4375 4873388.4999, 452607.5 4...
# 87  POLYGON ((494266.4373000003 4867973.499700001,...
# 88  POLYGON ((518372.7193 4879883.500499999, 51839...
# 89  POLYGON ((474207.0944999997 4846200.4999, 4742...
# 90  POLYGON ((600973.25 4977102.999399999, 600889....
# 91  POLYGON ((604018.6253000004 4976582.500600001,...
# 92  POLYGON ((392186.4371999996 4864922.000299999,...
# 93  POLYGON ((611999.5745999999 4925349.5067, 6119...
# 94  POLYGON ((412728.7494999999 4857265.5002, 4128...
# 95  POLYGON ((443801.4375999998 4903519.5, 443924....
# 96  POLYGON ((466552.8754000003 4869646.4998, 4665...
# 97  POLYGON ((556145.1017000005 5196146.820699999,...
# 98  (POLYGON ((424733.3274999997 4862545.2346, 424...
# 99  POLYGON ((466476.5938999997 4858381.9998, 4664...
#
# [100 rows x 30 columns]

# %%
grouped = megis_one.groupby('HOLD1_TYPE')['CALC_AC'].sum()
grouped.head()
# Out:
# HOLD1_TYPE
#              5.091229e+03
# Federal      2.027507e+05
# Municipal    4.022447e+04
# Other        1.470937e+04
# Private      2.382877e+06
# Name: CALC_AC, dtype: float64

# %%
grouped.to_frame('grouped_df')
# Out:
#               grouped_df
# HOLD1_TYPE
#             5.091229e+03
# Federal     2.027507e+05
# Municipal   4.022447e+04
# Other       1.470937e+04
# Private     2.382877e+06
# State       1.366761e+06

# %%
grouped.reset_index()
# Out:
#   HOLD1_TYPE       CALC_AC
# 0             5.091229e+03
# 1    Federal  2.027507e+05
# 2  Municipal  4.022447e+04
# 3      Other  1.470937e+04
# 4    Private  2.382877e+06
# 5      State  1.366761e+06

# %%
ax = grouped.plot(column='HOL')

# %%
ax = megis_one.plot(column='HOLD1_TYPE', figsize=(20,20), linewidth=0.25, edgecolor='white', legend=True)
plt.savefig('maine_all_lands_pub_priv_2.pdf')

# %%
megis_one['HOLD1_TYPE'].value_counts()

# %%
ax = megis_one.plot(figsize=(20,20), linewidth=0.25, edgecolor='white', color='lightgrey')
ax.axis('off')
plt.savefig('maine_all_lands.pdf')

# %%
megis_one.plot()

# %%
megis_one['HOLD1_NAME'].value_counts().head(10)
# Out:
# Maine Minor Civil Division                           2008
# Maine Bureau of Parks and Lands                      1446
# Maine Department of Inland Fisheries and Wildlife    1411
# US Fish and Wildlife Service                         1270
# Maine Coast Heritage Trust                            496
# US National Park Service                              400
# The Nature Conservancy                                312
#                                                       252
# Maine Farmland Trust                                  207
# New England Forestry Foundation, Inc.                 180
# Name: HOLD1_NAME, dtype: int64

# %%
megis_one[megis_one['HOLD1_NAME'] == 'Maine Coast Heritage Trust']
# Out:
#          ACQ_DATE ACQ_YEAR    BPL_ID     CALC_AC  CL_UNIQUEI CONS1_TYPE  \
# 85           None             63-107    0.174652          85        Fee
# 2498         None             59-657    0.064843        2511        Fee
# 2499         None             63-084    0.190661        2512        Fee
# 2500         None             63-099    0.290270        2513        Fee
# 3240         None                       0.758037        3281   Easement
# 3241         None                       1.669131        3282   Easement
# 3242         None                       3.031869        3283   Easement
# 3243         None                       2.862561        3284   Easement
# 3246         None                       7.167018        3287        Fee
# 3247         None                     110.006050        3288        Fee
# 3252         None                       0.064211        3293        Fee
# 3685         None                      11.409534        3731   Easement
# 4108         None                       3.888423        4159        Fee
# 4758         None                       1.172818        4813   Easement
# 4759         None     2001             13.848235        4814        Fee
# 4760         None     2001              0.168240        4815        Fee
# 4761         None     2011              0.446813        4816        Fee
# 4762         None                       9.867439        4817   Easement
# 4763         None                      35.931405        4818   Easement
# 4869         None     1991             26.757967        4924   Easement
# 4870         None     1982             56.578974        4925   Easement
# 4871         None     1987             38.201069        4926   Easement
# 4872         None     1988             17.466283        4927   Easement
# 4873         None     1992             86.282107        4928   Easement
# 4875         None     1984              7.372467        4930   Easement
# 4876         None     1991            152.550530        4931   Easement
# 4878         None     1989             26.313551        4933   Easement
# 4879         None     1989              3.920774        4934   Easement
# 4880         None     1999             22.032801        4935   Easement
# 4881         None     1993             30.524270        4936   Easement
# ...           ...      ...       ...         ...         ...        ...
# 7666         None     2014             26.505359        7791        Fee
# 7667         None                      96.182796        7792   Easement
# 7668         None                      33.801982        7793   Easement
# 7669         None                      32.921037        7794   Easement
# 7670         None                       2.756046        7795        Fee
# 7671         None                     107.861040        7796   Easement
# 7672         None                       6.782144        7797   Easement
# 7673         None                      14.284324        7798   Easement
# 7674         None     2014              1.673218        7799        Fee
# 7722         None     2007             87.481421        7847   Easement
# 7723   2008-12-17     2008  980-2516  507.807355        7848        Fee
# 10794        None     2015             19.705870       10932   Easement
# 10795        None     2015              0.221055       10941        Fee
# 10796        None     2015             11.658482       10931   Easement
# 10806        None     2015             17.376136       10942        Fee
# 10808        None     2016              0.587270       10949        Fee
# 10809        None     2015             94.362468       10945        Fee
# 10810        None     2015              2.039694       10946        Fee
# 10811        None     2015              3.931913       10939        Fee
# 10813        None     2015             15.445518       10937        Fee
# 10814        None     2015            194.468872       10935   Easement
# 10816        None     2015             14.880930       10933   Easement
# 10817        None     2015            146.736800       10938        Fee
# 10821        None     2015             18.410582       10943        Fee
# 10822        None     2015             11.538913       10940        Fee
# 10823        None     2015             71.860315       10944        Fee
# 10826        None     2015             34.582386       10934   Easement
# 10828        None     2015             78.174037       10936   Easement
# 10829        None     2016             15.359360       10948        Fee
# 10830        None     2016            427.597732       10947        Fee
#
#               CONS2_TYPE DEPT_ID      DESIGNATIO ECO_RESERV           EDITOR  \
# 85                                Coastal Island             Devon Witherell
# 2498                              Coastal Island             Devon Witherell
# 2499                              Coastal Island             Devon Witherell
# 2500                              Coastal Island             Devon Witherell
# 3240                                                         Justin Schlawin
# 3241                                                         Justin Schlawin
# 3242                                                         Justin Schlawin
# 3243                                                         Justin Schlawin
# 3246                                                         Justin Schlawin
# 3247                                                         Justin Schlawin
# 3252                                                         Justin Schlawin
# 3685                                                         Justin Schlawin
# 4108                                                         Justin Schlawin
# 4758                                                         Justin Schlawin
# 4759                                                         Justin Schlawin
# 4760                                                         Justin Schlawin
# 4761                                                         Justin Schlawin
# 4762                                                         Justin Schlawin
# 4763                                                         Justin Schlawin
# 4869                        1131                             Justin Schlawin
# 4870                        1356                             Justin Schlawin
# 4871                        1371                             Justin Schlawin
# 4872                        1374                             Justin Schlawin
# 4873                        1391                             Justin Schlawin
# 4875                        1396                             Justin Schlawin
# 4876                        1400                             Justin Schlawin
# 4878                        1423                             Justin Schlawin
# 4879                        1423                             Justin Schlawin
# 4880                        1800                             Justin Schlawin
# 4881                        1458                             Justin Schlawin
# ...                  ...     ...             ...        ...              ...
# 7666                                                         Justin Schlawin
# 7667                                                         Justin Schlawin
# 7668                                                         Justin Schlawin
# 7669                                                         Justin Schlawin
# 7670                                                         Justin Schlawin
# 7671                                                         Justin Schlawin
# 7672                                                         Justin Schlawin
# 7673                                                         Justin Schlawin
# 7674                                                         Justin Schlawin
# 7722                        2364                             Justin Schlawin
# 7723   Project Agreement    2375     Public Land                 Dan Sweeney
# 10794                                                        Justin Schlawin
# 10795           Easement                                     Justin Schlawin
# 10796                                                        Justin Schlawin
# 10806                                                        Justin Schlawin
# 10808
# 10809                                                        Justin Schlawin
# 10810                                                        Justin Schlawin
# 10811                                                        Justin Schlawin
# 10813                                                        Justin Schlawin
# 10814                                                        Justin Schlawin
# 10816                                                        Justin Schlawin
# 10817           Easement                                     Justin Schlawin
# 10821                                                        Justin Schlawin
# 10822                                                        Justin Schlawin
# 10823                                                        Justin Schlawin
# 10826                                                        Justin Schlawin
# 10828                                                        Justin Schlawin
# 10829
# 10830
#
#                                                 FMPROCSS    FMUPDDAT  \
# 85     put-copies selected features, coordinate infor...  2010-05-10
# 2498   put-copies selected features, coordinate infor...  2010-10-04
# 2499   put-copies selected features, coordinate infor...  2010-05-10
# 2500   put-copies selected features, coordinate infor...  2010-05-10
# 3240   copy-duplicates features and INFO files to a n...  2015-02-04
# 3241   copy-duplicates features and INFO files to a n...  2015-02-04
# 3242   copy-duplicates features and INFO files to a n...  2013-03-18
# 3243   copy-duplicates features and INFO files to a n...  2013-03-18
# 3246   copy-duplicates features and INFO files to a n...  2013-03-18
# 3247   copy-duplicates features and INFO files to a n...  2013-03-18
# 3252   copy-duplicates features and INFO files to a n...  2013-03-18
# 3685   copy-duplicates features and INFO files to a n...  2013-03-18
# 4108   copy-duplicates features and INFO files to a n...  2013-03-18
# 4758   copy-duplicates features and INFO files to a n...  2013-05-03
# 4759   copy-duplicates features and INFO files to a n...  2013-05-03
# 4760   copy-duplicates features and INFO files to a n...  2013-05-03
# 4761   copy-duplicates features and INFO files to a n...  2013-05-03
# 4762   copy-duplicates features and INFO files to a n...  2013-05-03
# 4763   copy-duplicates features and INFO files to a n...  2013-05-03
# 4869   copy-duplicates features and INFO files to a n...  2013-08-26
# 4870   copy-duplicates features and INFO files to a n...  2013-08-26
# 4871   copy-duplicates features and INFO files to a n...  2013-08-26
# 4872   copy-duplicates features and INFO files to a n...  2013-08-26
# 4873   copy-duplicates features and INFO files to a n...  2013-08-26
# 4875   copy-duplicates features and INFO files to a n...  2013-08-26
# 4876   copy-duplicates features and INFO files to a n...  2013-08-26
# 4878   copy-duplicates features and INFO files to a n...  2013-08-26
# 4879   copy-duplicates features and INFO files to a n...  2013-08-26
# 4880   copy-duplicates features and INFO files to a n...  2013-08-26
# 4881   copy-duplicates features and INFO files to a n...  2013-08-26
# ...                                                  ...         ...
# 7666   copy-duplicates features and INFO files to a n...        None
# 7667   copy-duplicates features and INFO files to a n...  2013-03-18
# 7668   copy-duplicates features and INFO files to a n...  2013-03-18
# 7669   copy-duplicates features and INFO files to a n...  2013-03-18
# 7670   copy-duplicates features and INFO files to a n...  2013-03-18
# 7671   copy-duplicates features and INFO files to a n...  2013-03-18
# 7672   copy-duplicates features and INFO files to a n...  2013-03-18
# 7673   copy-duplicates features and INFO files to a n...  2013-03-18
# 7674                                                      2015-02-04
# 7722   copy-duplicates features and INFO files to a n...  2013-08-26
# 7723   copy-duplicates features and INFO files to a n...  2009-04-10
# 10794  copy-duplicates features and INFO files to a n...  2016-05-20
# 10795  copy-duplicates features and INFO files to a n...  2016-05-20
# 10796  copy-duplicates features and INFO files to a n...  2016-05-20
# 10806  copy-duplicates features and INFO files to a n...  2016-05-20
# 10808                                                           None
# 10809  copy-duplicates features and INFO files to a n...  2016-05-20
# 10810  copy-duplicates features and INFO files to a n...  2016-05-20
# 10811  copy-duplicates features and INFO files to a n...  2016-05-20
# 10813  copy-duplicates features and INFO files to a n...  2016-05-20
# 10814  copy-duplicates features and INFO files to a n...  2016-05-20
# 10816  copy-duplicates features and INFO files to a n...  2016-05-20
# 10817  copy-duplicates features and INFO files to a n...  2016-05-20
# 10821  copy-duplicates features and INFO files to a n...  2016-05-20
# 10822  copy-duplicates features and INFO files to a n...  2016-05-20
# 10823  copy-duplicates features and INFO files to a n...  2016-05-20
# 10826  copy-duplicates features and INFO files to a n...  2016-05-20
# 10828  copy-duplicates features and INFO files to a n...  2016-05-20
# 10829                                                           None
# 10830                                                           None
#
#       GAP_STATUS                  HOLD1_NAME HOLD1_TYPE  \
# 85             2  Maine Coast Heritage Trust    Private
# 2498           2  Maine Coast Heritage Trust    Private
# 2499           2  Maine Coast Heritage Trust    Private
# 2500           2  Maine Coast Heritage Trust    Private
# 3240           3  Maine Coast Heritage Trust    Private
# 3241           3  Maine Coast Heritage Trust    Private
# 3242           3  Maine Coast Heritage Trust    Private
# 3243           3  Maine Coast Heritage Trust    Private
# 3246           2  Maine Coast Heritage Trust    Private
# 3247           2  Maine Coast Heritage Trust    Private
# 3252           2  Maine Coast Heritage Trust    Private
# 3685           3  Maine Coast Heritage Trust    Private
# 2499   Copied from VerifiedIsl boundaries. Verified b...
# 2500   Copied from VerifiedIsl boundaries. Verified b...
# 3240               Data provided by Blue Hill Land Trust
# 3241               Data provided by Blue Hill Land Trust
# 3242               Data provided by Blue Hill Land Trust
# 3243               Data provided by Blue Hill Land Trust
# 3246               Data provided by Blue Hill Land Trust
# 3247               Data provided by Blue Hill Land Trust
# 3252               Data provided by Blue Hill Land Trust
# 3685   Data provided by Blue Hill Land Trust-NHD wate...
# 4108               Data provided by Blue Hill Land Trust
# 4758                          Data provided by Interest1
# 4759                          Data provided by Interest1
# 4760                          Data provided by Interest1
# 4761                          Data provided by Interest1
# 4762                          Data provided by Interest1
# 4763                          Data provided by Interest1
# 4869                          Data provided by Interest1
# 4870                          Data provided by Interest1
# 4871                          Data provided by Interest1
# 4872                          Data provided by Interest1
# 4873                          Data provided by Interest1
# 4875                          Data provided by Interest1
# 4876                          Data provided by Interest1
# 4878                          Data provided by Interest1
# 4879                          Data provided by Interest1
# 4880                          Data provided by Interest1
# 4881                          Data provided by Interest1
# ...                                                  ...
# 7666                         Data provided by Interest 1
# 7667               Data provided by Blue Hill Land Trust
# 7668               Data provided by Blue Hill Land Trust
# 7669               Data provided by Blue Hill Land Trust
# 7670               Data provided by Blue Hill Land Trust
# 7671               Data provided by Blue Hill Land Trust
# 7672               Data provided by Blue Hill Land Trust
# 7673               Data provided by Blue Hill Land Trust
# 7674                         Data provided by Interest 1
# 7722                          Data provided by Interest1
# 7723   copied from BPL_Con_Lands_Region Layer-gap fix...
# 10794       Data provided by Interest1, source is survey
# 10795                        Data provided by Interest 1
# 10796       Data provided by Interest1, source is survey
# 10806                        Data provided by Interest 1
# 10808
# 10809                        Data provided by Interest 1
# 10810                        Data provided by Interest 1
# 10811                        Data provided by Interest 1
# 10813                        Data provided by Interest 1
# 10814       Data provided by Interest1, source is survey
# 10816       Data provided by Interest1, source is survey
# 10817                        Data provided by Interest 1
# 10821                        Data provided by Interest 1
# 10822                        Data provided by Interest 1
# 10823                        Data provided by Interest 1
# 10826   Data provided by Interest1, source is GPS points
# 10828       Data provided by Interest1, source is survey
# 10829
# 10830
#
#                                           PARCEL_NAM  \
# 85
# 2498
# 2499                        Part of Big Smith Island
# 2500
# 3240
# 3241
# 3242
# 3243
# 3246
# 3247
# 3252                                  Wadsworth Cove
# 3685                                        Brownell
# 4108
# 4758                             Federal Harbor West
# 4759                     Parker & Gooseberry Islands
# 4760                     Parker & Gooseberry Islands
# 4761   Sipp Bay - Former Knowlton Campground (Woods)
# 4762                             Dennys Bay - Popken
# 4763                               Long Cove - Caden
# 4869                               Norway Drive Farm
# 4870                                      Fog Island
# 4871                                North Shore View
# 4872                          Pulpit Harbor (Norton)
# 4873                                Whitehead Island
# 4875                               Fiddlehead Island
# 4876                               Leadbetter Island
# 4878                       The Basin at the Entrance
# 4879                       The Basin at the Entrance
# 4880                                  Western Island
# 4881                                Farnsworth Point
# ...                                              ...
# 7666                             Birch Point Pathman
# 7667
# 7668
# 7669
# 7670
# 7671
# 7672
# 7673
# 7674
# 
# 7668            0.000  POLYGON ((519709.1442 4919099.4531, 519719.576...
# 7669            0.000  POLYGON ((519757.5142000001 4918858.3346, 5199...
# 7670            0.000  POLYGON ((519449.7443000004 4918162.4748, 5193...
# 7671            0.000  POLYGON ((520473.3942999998 4918834.274900001,...
# 7672            0.000  POLYGON ((516520.2615 4916239.1251, 516550.650...
# 7673            0.000  POLYGON ((518204.2764999997 4914401.759, 51814...
# 7674            0.000  POLYGON ((520473.3942999998 4918834.274900001,...
# 7722            0.000  POLYGON ((647614.8015000001 4953356.9405, 6476...
# 7723          771.000  POLYGON ((646758.8059999999 4953355.2578, 6467...
# 10794           0.000  POLYGON ((430833.1727999998 4844000.611199999,...
# 10795           0.000  POLYGON ((536869.5625 4905411.5, 536868.5 4905...
# 10796           0.000  POLYGON ((430699.4658000004 4844179.098999999,...
# 10806           0.000  POLYGON ((484386.0203 4871045.729499999, 48410...
# 10808           0.000  POLYGON ((569021.8811999997 4919839.153899999,...
# 10809           0.000  POLYGON ((652560.3327000001 4958172.368000001,...
# 10810           0.000  POLYGON ((626708.5455 4954491.2928, 626828.725...
# 10811           0.000  POLYGON ((629433.8892999999 4949829.8343, 6295...
# 10813           0.000  POLYGON ((470142.7763999999 4863949.266799999,...
# 10814           0.000  POLYGON ((648836.7999 4967367.820800001, 64889...
# 10816           0.000  POLYGON ((515238.9062999999 4919764.5, 515245....
# 10817           0.000  POLYGON ((537037.0790999997 4904128.9121, 5370...
# 10821           0.000  POLYGON ((484011.7840999998 4871350.147700001,...
# 10822           0.000  POLYGON ((550307.3139000004 4884281.6162, 5502...
# 10823           0.000  POLYGON ((491981.3101000004 4891379.3335, 4919...
# 10826           0.000  POLYGON ((648710.5549999997 4967695.012700001,...
# 10828           0.000  POLYGON ((649024.9912 4965767.5382, 648925.115...
# 10829           0.000  POLYGON ((568577.4299999997 4919896.0414, 5685...
# 10830           0.000  POLYGON ((578043.6003999999 4920650.236, 57804...
#
# [496 rows x 30 columns]

# %%
megis_one['HOLD1_TYPE'].value_counts()
# Out:
# Private      3673
# State        3088
# Municipal    2021
# Federal      1772
# Other         249
#                28
# Name: HOLD1_TYPE, dtype: int64

# %%
megis_grouped = megis_one.groupby('HOLD1_TYPE')['CALC_AC'].sum()
type(megis_grouped)
# Out:
# pandas.core.series.Series

# %%
megis_grouped_df = megis_grouped.to_frame()
megis_grouped_df.head()
# Out:
#                  CALC_AC
# HOLD1_TYPE
#             5.091229e+03
# Federal     2.027507e+05
# Municipal   4.022447e+04
# Other       1.470937e+04
# Private     2.382877e+06

# %%
megis_grouped_df.sort_values(by='CALC_AC', ascending=False).plot(kind='bar', figsize=(20,20))
plt.savefig('megis_grouped_bar.pdf')

# %%
# megis_one[megis_one['HOLD1_TYPE'].str.contains('Other')]

# %%
megis_one['HOLD1_TYPE'].value_counts().plot(kind='bar', stacked=True)

# %%
# conservation_trusts.shape()

# %%
#what're the columns?
megis_one.columns
# Out:
# Index(['ACQ_DATE', 'ACQ_YEAR', 'BPL_ID', 'CALC_AC', 'CL_UNIQUEI', 'CONS1_TYPE',
#        'CONS2_TYPE', 'DEPT_ID', 'DESIGNATIO', 'ECO_RESERV', 'EDITOR',
#        'FMPROCSS', 'FMUPDDAT', 'GAP_STATUS', 'HOLD1_NAME', 'HOLD1_TYPE',
#        'HOLD2_NAME', 'HOLD2_TYPE', 'IFW_ID', 'IUCN_STATU', 'LMF_ID', 'NOTE_',
#        'PARCEL_NAM', 'PROJECT', 'PUB_ACCESS', 'PURPOSE1', 'PURPOSE2', 'REVIEW',
#        'RPT_AC', 'geometry'],
#       dtype='object')

# %%
#what are the designations?
megis_one['DESIGNATIO'].value_counts().head()
# Out:
#                                   3761
# Miscellaneous Municipal Lands     1568
# National Wildlife Refuge          1251
# State Wildlife Management Area     917
# Coastal Island                     566
# Name: DESIGNATIO, dtype: int64

# %% [markdown]
# ## Why are there some missing? Contact MEGIS!

# %%
#let's plot the designation types
counts = megis_one['DESIGNATIO'].value_counts().head(10)
colors = ['#191970','#001CF0','#0038E2','#0055D4','#0071C6','#008DB8','#00AAAA','#00C69C','#00E28E','#00FF80',]

ax = counts.plot(kind='bar', fontsize=17,colors=colors, figsize=(20,20))
fig = ax.get_figure()
fig.savefig('preserve_types_bar.png')

# %%
# counts = megis_one['DESIGNATIO'].value_counts().head(10)
# plt.axis('equal')
# colors = ['#191970','#001CF0','#0038E2','#0055D4','#0071C6','#008DB8','#00AAAA','#00C69C','#00E28E','#00FF80',]
# counts.plot(kind='pie', fontsize=17,colors=colors, figsize=(20,20))
# # plt.legend(labels=group_names,loc="DESIGNATIO")
# plt.show()
# plt.savefig('preserve_types.png')

# # explode = (0, 0, 0,0.1,0.1,0.2,0.3,0.4,0.6)

# # counts.plot(kind='pie', fontsize=17,colors=colors,explode=explode)

# %%
# ax = megis_one['DESIGNATIO'].value_counts().head(10).plot.pie(figsize=(20,10))
# ax.plot()
# ax.savefig('preserve_types_pie.pdf')

# %%
#are most of the holdings federal, state or private?
entity = megis_one['HOLD1_TYPE'].value_counts()
ax = entity.plot(kind='bar', figsize=(20,10))
fig = ax.get_figure()
fig.savefig('entity_bar.png')

# %%
megis_one['CONS1_TYPE'].value_counts()
# Out:
# Fee                              8297
# Easement                         2212
# Management Transfer Agreement     245
# Public Access Easement             41
#                                    20
# Restricted                          8
# Lease                               4
# Third Party Easement                2
# Other                               1
# Easement Enforcer                   1
# Name: CONS1_TYPE, dtype: int64

# %%
megis_one['HOLD1_NAME'].value_counts()
# Out:
# Maine Minor Civil Division                                 2008
# Maine Bureau of Parks and Lands                            1446
# Maine Department of Inland Fisheries and Wildlife          1411
# US Fish and Wildlife Service                               1270
# Maine Coast Heritage Trust                                  496
# US National Park Service                                    400
# The Nature Conservancy                                      312
#                                                             252
# Maine Farmland Trust                                        207
# New England Forestry Foundation, Inc.                       180
# Blue Hill Heritage Trust                                    130
# Great Works Regional Land Trust                             123
# Kennebunkport Conservation Trust                            121
# Baxter State Park Authority                                 109
# Downeast Coastal Conservancy                                 95
# Forest Society of Maine                                      89
# Kennebec Land Trust                                          82
# Greater Lovell Land Trust                                    79
# Medomak Valley Land Trust                                    76
# Portland Water District                                      76
# Sweet Water Trust                                            75
# Androscoggin Land Trust                                      73
# Kennebunk, Kennebunkport and Wells Water Districts           72
# York Land Trust, Inc.                                        71
# US Department of Interior                                    71
# Maine Atlantic Salmon Commission                             58
# Kennebunk Land Trust                                         58
# Georges River Land Trust                                     56
# Coastal Mountains Land Trust                                 50
# Frenchman Bay Conservancy                                    50
#                                                            ...
# Biddeford Water District                                      3
# The Archaeological Conservancy                                3
# Unknown                                                       3
# Portland Trails                                               3
# Oceanside Conservation Trust of Casco Bay                     2
# Islesboro Islands Trust                                       2
# Ecotat Trust                                                  2
# Federal Aviation Administration (USDOT)                       2
# Bangor Water District                                         2
# US Veteran's Administration                                   2
# Western Mountains Foundation - ME huts and trails             2
# Penobscot River Restoration Trust                             2
# Appalachian Trail Conservancy                                 2
# Foothills Land Conservancy                                    1
# University of Maine at Orono                                  1
# Prouts Neck Association                                       1
# Maine Appalachian Trail Land Trust                            1
# Hirundo Wildlife Refuge                                       1
# Four Seasons Trail Association                                1
# Windham Land Trust                                            1
# Small Point Association                                       1
# Friends of Seguin Island                                      1
# Crabtree Neck Land Trust                                      1
# US Fish and Wildlife Service, Gulf of Maine Project           1
# Holt Research Foundation                                      1
# Passamaquoddy Indian Tribe                                    1
# Quoddy Regional Land Trust                                    1
# Woodie Wheaton Land Trust                                     1
# Society for the Preservation of New England Antiquities       1
# Chewonki Foundation                                           1
# Name: HOLD1_NAME, Length: 123, dtype: int64

# %%
#which organizations manage the most parcels?
holders = megis_one['HOLD1_NAME'].value_counts().head(20)
color = ['#191970','#001CF0','#0038E2','#0055D4','#0071C6','#008DB8','#00AAAA','#00C69C','#00E28E','#00FF80',]
ax = holders.plot(kind='bar', fontsize=17, color=color, figsize=(20,10))
fig = ax.get_figure()
fig.savefig('land_holder_bar.png')

# %%
holders = megis_one['HOLD1_NAME'].value_counts().head(10)
plt.axis('equal')
colors = ['#e6194b','#3cb44b','#ffe119','#0082c8','#f58231','#911eb4','#46f0f0','#f032e6','#d2f53c','#fabebe',"#008080",'#e6beff','#aa6e28','#fffac8','#800000','#aaffc3','#808000','#ffd8b1','#000080','#808080','#FFFFFF','#000000']
ax = holders.plot(kind='pie', fontsize=17,colors=colors, figsize=(20,20))
# plt.legend(labels=group_names,loc="DESIGNATIO")
fig = ax.get_figure()
fig.savefig('land_holder_pie2.png')

# %%
#let's map all of them using the shapefile
ax = megis_one.plot(color='red', linewidth=0.25, edgecolor='white', figsize=(20,20))
ax.plot()
ax.savefig('megis_one.png')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-542fd10b6456> in <module>()
#       1 #let's map all of them using the shapefile
# ----> 2 ax = megis_one.plot(color='red', linewidth=0.25, edgecolor='white', figsize=(20,20))
#       3 ax.plot()
#       4 ax.savefig('megis_one.png')
#       5
#
# /usr/local/lib/python3.6/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     445     def plot(self, *args, **kwargs):
#     446
# --> 447         return plot_dataframe(self, *args, **kwargs)
#     448
#     449     plot.__doc__ = plot_dataframe.__doc__
#
# /usr/local/lib/python3.6/site-packages/geopandas/plotting.py in plot_dataframe(s, column, cmap, color, linewidth, categorical, legend, ax, scheme, k, vmin, vmax, figsize, **color_kwds)
#     238         return plot_series(s.geometry, cmap=cmap, color=color,
#     239                            ax=ax, linewidth=linewidth, figsize=figsize,
# --> 240                            **color_kwds)
#     241     else:
#     242         if s[column].dtype is np.dtype('O'):
#
# /usr/local/lib/python3.6/site-packages/geopandas/plotting.py in plot_series(s, cmap, color, ax, linewidth, figsize, **color_kwds)
#     141                 plot_multipolygon(ax, geom, linewidth=linewidth, **color_kwds)
#     142             else:
# --> 143                 plot_multipolygon(ax, geom, facecolor=col, linewidth=linewidth, **color_kwds)
#     144         elif geom.type == 'LineString' or geom.type == 'MultiLineString':
#     145             plot_multilinestring(ax, geom, color=col, linewidth=linewidth, **color_kwds)
#
# /usr/local/lib/python3.6/site-packages/geopandas/plotting.py in plot_multipolygon(ax, geom, facecolor, edgecolor, alpha, linewidth, **kwargs)
#      28     """
#      29     if geom.type == 'Polygon':
# ---> 30         plot_polygon(ax, geom, facecolor=facecolor, edgecolor=edgecolor, alpha=alpha, linewidth=linewidth, **kwargs)
#      31     elif geom.type == 'MultiPolygon':
#      32         for poly in geom.geoms:
#
# /usr/local/lib/python3.6/site-packages/geopandas/plotting.py in plot_polygon(ax, poly, facecolor, edgecolor, alpha, linewidth, **kwargs)
#      18     # without Descartes, we could make a Patch of exterior
#      19     ax.add_patch(PolygonPatch(poly, facecolor=facecolor, linewidth=0, alpha=alpha))  # linewidth=0 because boundaries are drawn separately
# ---> 20     ax.plot(a[:, 0], a[:, 1], color=edgecolor, linewidth=linewidth, **kwargs)
#      21     for p in poly.interiors:
#      22         x, y = zip(*p.coords)
#
# /usr/local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1408             lines.append(line)
#    1409
# -> 1410         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1411         return lines
#    1412
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2264
#    2265         if self.use_sticky_edges and (self._xmargin or self._ymargin):
# -> 2266             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2267             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2268             y_stickies = sum([sticky.y for sticky in stickies], [])
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#    2264
#    2265         if self.use_sticky_edges and (self._xmargin or self._ymargin):
# -> 2266             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2267             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2268             y_stickies = sum([sticky.y for sticky in stickies], [])
#
# /usr/local/lib/python3.6/site-packages/matplotlib/artist.py in sticky_edges(self)
#     928         self.stale = True
#     929
# --> 930     @property
#     931     def sticky_edges(self):
#     932         """
#
# KeyboardInterrupt:

# %% [markdown]
# ### After scraping info from MLTN (a subsidiary of MCHT), I cleaned the file in excel and then reuploaded it below. see maine_conservation_scraping notebook for info

# %%
#I cleaned the file a little in excel
#because I find that easier sometimes
#so let's re-import it

mltn_scraped = pd.read_csv('/Users/kaitlincough/Documents/data_studio/data_studio_projects/code/maine_conservation_lands/maine_land_trust_info.csv')
mltn_scraped.head(50)

# %%
#make sure it's still the same leng
len(mltn_scraped)

# %%
#so the next step is to join the geodataframe megis_one with the df with all the trust info
#on the name column
#then you can create a nice map with all that info

# %%
#first thing to do is reset the index on the 
#spatial dataframe so

# %%
# megis_one.rename(columns={'HOLD1_NAME': 'name'}, inplace=True)
# megis_one.head()

# %%
# # continental.merge(obesity, left_on='NAME', right_on='statename')

# joined = megis_one.merge(mltn_scraped, left_on='name', right_on='name')
# joined.head(100)

# %%
# joined.shape

# %%
#then color it by the name of the trust

# %%
# mft = joined[joined['name'] =='Maine Farmland Trust']
# mft['geometry'].plot()

# %%
# mcht = joined[joined['name']=='Maine Coast Heritage Trust']
# mcht.head(496)

# %%
# pd.set_option("display.max_rows", 100)
# mcht.head(500)

# %%
# mcht.to_csv("mcht_only_from_joined_dataset.csv", index=False)

# %%
# mcht['geometry'].plot(figsize=(20,20))

# %% [markdown]
# ### Below is the shapefile for the actual state of Maine if we need it.

# %%
# maine = gpd.read_file('/Users/kaitlincough/Documents/data_studio/data_studio_projects/shapefiles/maine_shapefile/Cnty24L.shp')

# %%
# maine.head()

# %%
# maine.plot()

# %%
# ax = maine.plot(figsize=(25,10), color='#A9A9A9')

# mcht.plot(figsize=(25,20),ax=ax)
# ax.axis('off')
# # ax.savefig('mchtonly.png')

# %%
# #plot the joined dataframe on top of the map of maine
# #coloring by the name column, ie by the trust/govt entity that controls it
# ax = maine.plot(figsize=(20,20), color='#A9A9A9')

# joined.plot(column='name', cmap='autumn_r', figsize=(20,20), ax=ax)
# ax.axis('off')
ax.savefig('maine_conservation.png')

# %%
megis_one.head()

# %%
megis_one.shape

# %%
#here's the info from Bob Bistrais with the updated holding 
megis_two = gpd.read_file('/Users/kaitlincough/Documents/data_studio/big_files_that_make_github_sad/shapefiles/megis_conserved_lands_new/conserved_landss_new/ConservedLands.shp')

# %%
megis_two.head()
# Out:
#      ACQ_DATE ACQ_YEAR BPL_ID    CALC_AC  CL_UNIQUEI CONS1_TYPE CONS2_TYPE  \
# 0        None     1965          8.314696           1          F
# 1        None                  52.293330           2          F
# 2        None     2001          1.816991           4          E
# 3        None     2001          0.084249           5          E
# 4  1989-09-06     1989         30.675615           6          E
#
#   DEPT_ID DESIGNATIO ECO_RESERV  \
# 0                NAT
# 1
# 2
# 3
# 4                 CE
#
#                          ...                         PUB_ACCESS  \
# 0                        ...                                  A
# 1                        ...                                  C
# 2                        ...                                  C
# 3                        ...                                  C
# 4                        ...                                  C
#
#                 PURPOSE1 PURPOSE2 REVIEW  RPT_AC     Shape_STAr   Shape_STLe  \
# 0  Conservation/Wildlife                   0.000   33648.380756   878.782412
# 1                                         52.292  211623.602097  1966.799575
# 2                                          1.817    7353.103227   379.180470
# 3                                          0.085     340.941805    83.147275
# 4                                         37.000  124139.807726  2453.458032
#
#   TAX_MAP_BO TAX_MAP_TO                                           geometry
# 0                        POLYGON ((462543.8321000002 4861397.2675, 4625...
# 1                        POLYGON ((542053.9376999997 5089059.000499999,...
# 2                        POLYGON ((492307.3439999996 5140590.4999, 4923...
# 3                        POLYGON ((531716.8749000002 5134688.4998, 5317...
# 4                        POLYGON ((583480.4373000003 5176787.9998, 5834...
#
# [5 rows x 36 columns]

# %%
megis_two.shape

# %%
pd.set_option("display.max_columns", 100)
megis_two.head()
# Out:
#      ACQ_DATE ACQ_YEAR BPL_ID    CALC_AC  CL_UNIQUEI CONS1_TYPE CONS2_TYPE  \
# 0        None     1965          8.314696           1          F
# 1        None                  52.293330           2          F
# 2        None     2001          1.816991           4          E
# 3        None     2001          0.084249           5          E
# 4  1989-09-06     1989         30.675615           6          E
#
#   DEPT_ID DESIGNATIO ECO_RESERV      EDITOR FMPROCSS    FMUPDDAT GAP_STATUS  \
# 0                NAT                   LUPC                 None          2
# 1                                                           None          4
# 2                                                           None          3
# 3                                                           None          3
# 4                 CE             MNAP_chris      put  2009-07-16          3
#
#                                  GlobalID HOLD1_NAME HOLD1_TYPE HOLD2_NAME  \
# 0  {5455AADD-84F9-4715-8C06-05E8417D2E92}        tnc          P
# 1  {E3502C95-6B2B-447B-BF6D-063963651B10}      medot          S
# 2  {67C872E9-707F-42CC-BFAC-E3209A076E57}       neff          P
# 3  {5516CF27-CB07-46E5-B427-043ECC8967E5}       neff          P
# 4  {E5B1AAF2-3FC2-448C-A8BD-640D1254D965}      meifw          S
#
#   HOLD2_TYPE   IFW_ID IUCN_STATU LMF_ID  \
# 0
# 1
# 2
# 3
# 4             0013001
#
#                                                NOTE_  OBJECTID  \
# 0                              MEFO File Survey; CAP         1
# 1                                 Roadside Rest Area         2
# 2                                                            4
# 3                                                            5
# 4  Digitized boundaries from georeferenced 1973 s...         6
#
#           PARCEL_NAM               PROJECT PUB_ACCESS               PURPOSE1  \
# 0                        La Verna Preserve          A  Conservation/Wildlife
# 1           ASH HILL  ASH HILL SCENIC AREA          C
# 2   PINGREE EASEMENT      PINGREE EASEMENT          C
# 3   PINGREE EASEMENT      PINGREE EASEMENT          C
# 4  McBurnie Property          Conant Brook          C
#
#   PURPOSE2 REVIEW  RPT_AC     Shape_STAr   Shape_STLe TAX_MAP_BO TAX_MAP_TO  \
# 0                   0.000   33648.380756   878.782412
# 1                  52.292  211623.602097  1966.799575
# 2                   1.817    7353.103227   379.180470
# 3                   0.085     340.941805    83.147275
# 4                  37.000  124139.807726  2453.458032
#
#                                             geometry
# 0  POLYGON ((462543.8321000002 4861397.2675, 4625...
# 1  POLYGON ((542053.9376999997 5089059.000499999,...
# 2  POLYGON ((492307.3439999996 5140590.4999, 4923...
# 3  POLYGON ((531716.8749000002 5134688.4998, 5317...
# 4  POLYGON ((583480.4373000003 5176787.9998, 5834...

# %%
megis_two.plot()

# %%
megis_two.columns

# %%
#let's join the old MEGIS shapefile (with full names)
#with the new one, using the CL_UNIQUEI column
joined2 = megis_one.merge(megis_two, on='CL_UNIQUEI', how='outer')
joined2.head()

# %%
joined2.shape

# %%
megis_one.shape

# %%
megis_two.shape

# %%
mcht = joined2[joined2['HOLD1_NAME_x']=='Maine Coast Heritage Trust']
mcht.head(496)

# %%
mcht.shape

# %%
pd.set_option('display.max_rows',100)
mcht[mcht['PROJECT_x'].str.contains('sea*')==True]

# %%
mcht.plot(x='ACQ_YEAR_x', y='CALC_AC_x', figsize=(20,10))

# %%
ax = megis_two.plot(figsize=(25,10), edgecolor='white')
megis_two.plot(figsize=(25,10), ax=ax)
ax.axis('off')
ax.savefig('maine_map.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f3396f929bf9> in <module>()
#       2 megis_two.plot(figsize=(25,10), ax=ax)
#       3 ax.axis('off')
# ----> 4 ax.savefig('maine_map.pdf')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
ax = megis_two.plot(linewidth=0.25, edgecolor='white', figsize=(20,20))
ax.savefig('megis_one.pdf')
