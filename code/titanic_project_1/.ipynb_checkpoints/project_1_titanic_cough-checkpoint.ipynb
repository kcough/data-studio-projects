# %% [markdown]
# #### Kate Cough
# #### Project One
#
# ## Summary
#
# I have a dataset with information about passengers on the Titanic that includes the fare they paid and whether they survived the sinking; I would like to calculate the relationship between ticket price and the likelihood that one survived.
#
# I'm imagining the final product to look like this:

# %% [markdown]
# ## Details
#
# Possible headline(s):
# Passengers who paid higher fares more likely to survive sinking of Titanic
#
# Paying for to survive: passengers who paid higher fare more likely to survive Titanic sinking
#
# Data set(s): From the department of Biostats at Vanderbilt (http://biostat.mc.vanderbilt.edu/wiki/Main/DataSets), using information from Encyclopedia Titanica (https://www.encyclopedia-titanica.org/)
#
# Code repository: https://github.com/jsoma/sample-pages/tree/master/code/a-very-cool-project
#
# Possible problems/fears/questions: Calculating probabilities

# %% [markdown]
# ## Work so far
#
# I've cleaned the data a little and explored it. Made some charts relating to number of tickets sold and the fare passengers paid, looked a little at the age and sex columns, and made a scatter plot relating ticket price and survival. The end product I'm imagining to look like this:

# %% [markdown]
# **Data Dictionary**
#
# survival: Survival	0 = No, 1 = Yes
# pclass: Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# sex: Sex (male/female)
# Age: Age in years
# sibsp: # of siblings / spouses aboard the Titanic
# parch: # of parents / children aboard the Titanic
# ticket: Ticket number
# fare: Passenger fare
# cabin: Cabin number
# embarked: Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton
#
# **Variable Notes**
#
# pclass: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# sibsp: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.
#
# source: https://www.kaggle.com/c/titanic/data
#
# the data came from here: https://www.encyclopedia-titanica.org/

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('ggplot')
# %matplotlib inline
df = pd.read_csv('/Users/kaitlincough/Documents/data_studio_projects_2017/data-studio-projects/code/titanic_project_1/titanic3.csv')

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
#could we create a dataframe with the value counts of
#the fare and merge that with the survivors?
# df['fare'].value_counts()

# %%
#what (column to group by), [what column you want info about], .what kind of info you want()
# df.groupby("Continent")["GDP_per_capita"].describe()
#let's look at this. groupby fare and get information on the survived column
# data[data['Type'].str.contains('Fruit')]

#let's groupby the fare and see the number of 
#people who survived for each fare (we can sum because the
#values are 0 and 1 so sum will give us the number
#of survivors)
fare_grouped = df.groupby('fare')['survived'].sum()
fare_grouped.head(30)
# Out:
# fare
# 0.0000    2
# 3.1708    1
# 4.0125    0
# 5.0000    0
# 6.2375    0
# 6.4375    0
# 6.4500    0
# 6.4958    0
# 6.7500    0
# 6.8583    0
# 6.9500    1
# 6.9750    1
# 7.0000    1
# 7.0458    0
# 7.0500    1
# 7.0542    0
# 7.1250    0
# 7.1417    1
# 7.2250    5
# 7.2292    7
# 7.2500    1
# 7.2833    0
# 7.3125    0
# 7.4958    1
# 7.5208    0
# 7.5500    2
# 7.5750    0
# 7.5792    1
# 7.6292    0
# 7.6500    3
# Name: survived, dtype: int64

# %%
#turn this series into a dataframe 

fare_grouped = fare_grouped.to_frame('fare_grouped')

# %%
fare_grouped.head()
# Out:
#         fare_grouped
# fare
# 0.0000             2
# 3.1708             1
# 4.0125             0
# 5.0000             0
# 6.2375             0

# %%
#check to see if it worked
fare_grouped.head()
# Out:
#      fare  fare_grouped  number_tickets_purchased
# 0  0.0000             2                        17
# 1  3.1708             1                         1
# 2  4.0125             0                         1
# 3  5.0000             0                         1
# 4  6.2375             0                         1

# %%
#create a new column with the number of tickets purchased
#based on the value counts for the fare column in the OG df

fare_grouped['number_tickets_purchased'] = df['fare'].value_counts()
fare_grouped
# Out:
#           fare_grouped  number_tickets_purchased
# fare
# 0.0000               2                        17
# 3.1708               1                         1
# 4.0125               0                         1
# 5.0000               0                         1
# 6.2375               0                         1
# 6.4375               0                         3
# 6.4500               0                         1
# 6.4958               0                         3
# 6.7500               0                         2
# 6.8583               0                         1
# 6.9500               1                         2
# 6.9750               1                         2
# 7.0000               1                         2
# 7.0458               0                         1
# 7.0500               1                         9
# 7.0542               0                         2
# 7.1250               0                         4
# 7.1417               1                         1
# 7.2250               5                        21
# 7.2292               7                        24
# 7.2500               1                        18
# 7.2833               0                         1
# 7.3125               0                         1
# 7.4958               1                         3
# 7.5208               0                         1
# 7.5500               2                         8
# 7.5750               0                         1
# 7.5792               1                         1
# 7.6292               0                         2
# 7.6500               3                         6
# ...                ...                       ...
# 82.1708              1                         2
# 82.2667              2                         2
# 83.1583              5                         6
# 83.4750              1                         2
# 86.5000              3                         3
# 89.1042              2                         2
# 90.0000              4                         5
# 91.0792              2                         2
# 93.5000              2                         4
# 106.4250             2                         3
# 108.9000             2                         3
# 110.8833             3                         4
# 113.2750             2                         3
# 120.0000             4                         4
# 133.6500             2                         2
# 134.5000             5                         5
# 135.6333             3                         4
# 136.7792             1                         2
# 146.5208             2                         3
# 151.5500             3                         6
# 153.4625             2                         3
# 164.8667             3                         4
# 211.3375             4                         4
# 211.5000             2                         5
# 221.7792             1                         4
# 227.5250             3                         5
# 247.5208             2                         3
# 262.3750             6                         7
# 263.0000             4                         6
# 512.3292             4                         4
#
# [281 rows x 2 columns]

# %%
fare_grouped=fare_grouped.reset_index()

# %%
fare_grouped
# Out:
#          fare  fare_grouped  number_tickets_purchased
# 0      0.0000             2                        17
# 1      3.1708             1                         1
# 2      4.0125             0                         1
# 3      5.0000             0                         1
# 4      6.2375             0                         1
# 5      6.4375             0                         3
# 6      6.4500             0                         1
# 7      6.4958             0                         3
# 8      6.7500             0                         2
# 9      6.8583             0                         1
# 10     6.9500             1                         2
# 11     6.9750             1                         2
# 12     7.0000             1                         2
# 13     7.0458             0                         1
# 14     7.0500             1                         9
# 15     7.0542             0                         2
# 16     7.1250             0                         4
# 17     7.1417             1                         1
# 18     7.2250             5                        21
# 19     7.2292             7                        24
# 20     7.2500             1                        18
# 21     7.2833             0                         1
# 22     7.3125             0                         1
# 23     7.4958             1                         3
# 24     7.5208             0                         1
# 25     7.5500             2                         8
# 26     7.5750             0                         1
# 27     7.5792             1                         1
# 28     7.6292             0                         2
# 29     7.6500             3                         6
# ..        ...           ...                       ...
# 251   82.1708             1                         2
# 252   82.2667             2                         2
# 253   83.1583             5                         6
# 254   83.4750             1                         2
# 255   86.5000             3                         3
# 256   89.1042             2                         2
# 257   90.0000             4                         5
# 258   91.0792             2                         2
# 259   93.5000             2                         4
# 260  106.4250             2                         3
# 261  108.9000             2                         3
# 262  110.8833             3                         4
# 263  113.2750             2                         3
# 264  120.0000             4                         4
# 265  133.6500             2                         2
# 266  134.5000             5                         5
# 267  135.6333             3                         4
# 268  136.7792             1                         2
# 269  146.5208             2                         3
# 270  151.5500             3                         6
# 271  153.4625             2                         3
# 272  164.8667             3                         4
# 273  211.3375             4                         4
# 274  211.5000             2                         5
# 275  221.7792             1                         4
# 276  227.5250             3                         5
# 277  247.5208             2                         3
# 278  262.3750             6                         7
# 279  263.0000             4                         6
# 280  512.3292             4                         4
#
# [281 rows x 3 columns]

# %%
#rename the columns immediately because otherwise
#it's confusing

fare_grouped.rename(columns={'fare_grouped':'number_survivors'}, inplace=True)
fare_grouped.head()
# Out:
#      fare  number_survivors  number_tickets_purchased
# 0  0.0000                 2                        17
# 1  3.1708                 1                         1
# 2  4.0125                 0                         1
# 3  5.0000                 0                         1
# 4  6.2375                 0                         1

# %%
fare_grouped.columns
# Out:
# Index(['fare', 'number_survivors', 'number_tickets_purchased'], dtype='object')

# %%
#create a new column with the survival rate
#by dividing the # of survivors
#by the # of people who purchased a ticket at 
#that fare survivors / number_tickets_purchased

fare_grouped['survival_%_rate'] = (fare_grouped['number_survivors']/fare_grouped['number_tickets_purchased']) * 100

# %%
fare_grouped.head(30)
# Out:
#       fare  number_survivors  number_tickets_purchased  survival_%_rate
# 0   0.0000                 2                        17        11.764706
# 1   3.1708                 1                         1       100.000000
# 2   4.0125                 0                         1         0.000000
# 3   5.0000                 0                         1         0.000000
# 4   6.2375                 0                         1         0.000000
# 5   6.4375                 0                         3         0.000000
# 6   6.4500                 0                         1         0.000000
# 7   6.4958                 0                         3         0.000000
# 8   6.7500                 0                         2         0.000000
# 9   6.8583                 0                         1         0.000000
# 10  6.9500                 1                         2        50.000000
# 11  6.9750                 1                         2        50.000000
# 12  7.0000                 1                         2        50.000000
# 13  7.0458                 0                         1         0.000000
# 14  7.0500                 1                         9        11.111111
# 15  7.0542                 0                         2         0.000000
# 16  7.1250                 0                         4         0.000000
# 17  7.1417                 1                         1       100.000000
# 18  7.2250                 5                        21        23.809524
# 19  7.2292                 7                        24        29.166667
# 20  7.2500                 1                        18         5.555556
# 21  7.2833                 0                         1         0.000000
# 22  7.3125                 0                         1         0.000000
# 23  7.4958                 1                         3        33.333333
# 24  7.5208                 0                         1         0.000000
# 25  7.5500                 2                         8        25.000000
# 26  7.5750                 0                         1         0.000000
# 27  7.5792                 1                         1       100.000000
# 28  7.6292                 0                         2         0.000000
# 29  7.6500                 3                         6        50.000000

# %%
fare_grouped.plot(x='survival_%_rate', y='fare', kind='barh', figsize=(20,20))

# %%
plt.scatter(fare_grouped['survival_%_rate'], fare_grouped['fare'], alpha=0.5, mark)

# %%
#This might help with markersize stuff:
#http://matplotlib.org/1.4.2/examples/pylab_examples/scatter_demo2.html

# %% [markdown]
# ### Here's some interesting info on fare prices and how they were calculated for this dataset:
# http://www.statisticalconsultants.co.nz/blog/titanic-fare-data.html

# %%
ax = df['fare'].plot(figsize=(20,10), kind='hist', bins=100, title='Fares paid for passage on the Titanic')
ax.set_xlabel('fare in british pounds')
ax.set_ylabel('number of tickets sold')

# %%
#what was the average age of passengers?
df['age'].describe()
# Out:
# count    1046.000000
# mean       29.881138
# std        14.413493
# min         0.170000
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: age, dtype: float64

# %%
#how many men? women?
df['sex'].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
#average fare price? max?
df['fare'].describe()
# Out:
# count    1308.000000
# mean       33.295479
# std        51.758668
# min         0.000000
# 25%         7.895800
# 50%        14.454200
# 75%        31.275000
# max       512.329200
# Name: fare, dtype: float64

# %%
#let's look at all of the different fares and how many people paid 
#each fare value. there are lots of random ones.
df['fare'].value_counts().sort_values(ascending=True)
# Out:
# 34.6542     1
# 14.0000     1
# 25.7417     1
# 28.5375     1
# 8.1375      1
# 7.3125      1
# 26.3875     1
# 7.7792      1
# 7.2833      1
# 6.2375      1
# 12.5250     1
# 8.3000      1
# 8.3625      1
# 7.7875      1
# 8.1583      1
# 6.8583      1
# 12.0000     1
# 15.0000     1
# 25.5875     1
# 8.0292      1
# 28.7125     1
# 7.7292      1
# 7.5208      1
# 12.2750     1
# 7.8750      1
# 9.4833      1
# 8.4583      1
# 9.3250      1
# 27.4458     1
# 3.1708      1
#            ..
# 56.4958     8
# 46.9000     8
# 7.0500      9
# 15.2458     9
# 24.1500     9
# 7.7958     10
# 7.8792     10
# 14.4542    10
# 15.5000    10
# 27.7208    11
# 14.5000    11
# 69.5500    11
# 16.1000    12
# 9.5000     12
# 21.0000    14
# 0.0000     17
# 7.2500     18
# 8.6625     21
# 7.8542     21
# 7.2250     21
# 26.5500    22
# 7.9250     23
# 7.2292     24
# 7.7750     26
# 10.5000    35
# 7.8958     49
# 26.0000    50
# 7.7500     55
# 13.0000    59
# 8.0500     60
# Name: fare, Length: 281, dtype: int64

# %%
#let's try this: there are 50 people who paid
#26.0000 for a ticket.
# newdf = df[df['id'] == id]

twenty_six_pounds = df[df['fare'] == 26.0000]
twenty_six_pounds.head()
# Out:
#      pclass  survived                        name   sex   age  sibsp  parch  \
# 25        1         0         Birnbaum, Mr. Jakob  male  25.0      0      0
# 58        1         0      Case, Mr. Howard Brown  male  49.0      0      0
# 171       1         0  Jones, Mr. Charles Cresson  male  46.0      0      0
# 172       1         0    Julian, Mr. Henry Forbes  male  50.0      0      0
# 194       1         0    Maguire, Mr. John Edward  male  30.0      0      0
#
#      ticket  fare cabin embarked boat   body                         home.dest
# 25    13905  26.0   NaN        C  NaN  148.0                 San Francisco, CA
# 58    19924  26.0   NaN        S  NaN    NaN  Ascot, Berkshire / Rochester, NY
# 171     694  26.0   NaN        S  NaN   80.0                    Bennington, VT
# 172  113044  26.0   E60        S  NaN    NaN                            London
# 194  110469  26.0  C106        S  NaN    NaN                      Brockton, MA

# %%
#let's take a value counts on the survival column of 
#our new df

twenty_six_pounds['survived'].value_counts()
# Out:
# 0    31
# 1    19
# Name: survived, dtype: int64

# %% [markdown]
# So out of 50 people who paid 26.0000 pounds, 19 survived and 31 perished.

# %%
#to get the survival percentage rate,
#divide the number of survivors by the number
#of people paying that ticket price 
(19/50) * 100
# Out:
# 38.0

# %%
plt.scatter(df.fare, df.survived, alpha=0.5)

# %%
df.plot(x='fare', y='survived', figsize=(20,10), kind='scatter')
