# %%
Did the wealthy men on the titanic get off before the poor women?
# Out:
# Object `women` not found.

# %%
Did the wealthy men on the titanic get off before the poor women

# %% [markdown]
# #### Kate Cough
# #### Project One: Titanic
# #### July 2017
#
# ## Summary
#
# I have a dataset with information about passengers on the Titanic that includes the fare they paid and whether they survived the sinking; I would like to calculate the relationship between ticket price and the likelihood that one survived.
#
# I'm imagining the final product to look like this:

# %% [markdown]
# ## Details
#
# Possible headline(s):
# Passengers who paid higher fares more likely to survive sinking of Titanic
#
# Paying for to survive: passengers who paid higher fare more likely to survive Titanic sinking
#
# Data set(s): From the department of Biostats at Vanderbilt (http://biostat.mc.vanderbilt.edu/wiki/Main/DataSets), using information from Encyclopedia Titanica (https://www.encyclopedia-titanica.org/)
#
# Code repository: https://github.com/jsoma/sample-pages/tree/master/code/a-very-cool-project
#
# Possible problems/fears/questions: Calculating probabilities

# %% [markdown]
# **Data Dictionary**
#
#     survival: Survival	0 = No, 1 = Yes
#     pclass: Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
#     sex: Sex (male/female)
#     Age: Age in years
#     sibsp: # of siblings / spouses aboard the Titanic
#     parch: # of parents / children aboard the Titanic
#     ticket: Ticket number
#     fare: Passenger fare
#     cabin: Cabin number
#     embarked: Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton
#
# **Variable Notes**
#
#     pclass: A proxy for socio-economic status (SES)
#     1st = Upper
#     2nd = Middle
#     3rd = Lower
#
#     age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
#     sibsp: The dataset defines family relations in this way...
#     Sibling = brother, sister, stepbrother, stepsister
#     Spouse = husband, wife (mistresses and fiancés were ignored)
#
#     parch: The dataset defines family relations in this way...
#     Parent = mother, father
#     Child = daughter, son, stepdaughter, stepson
#     Some children travelled only with a nanny, therefore parch=0 for them.
#
#     source: https://www.kaggle.com/c/titanic/data
#
#     the data came from here: https://www.encyclopedia-titanica.org/

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42

import numpy as np

plt.style.use('ggplot')
# %matplotlib inline
df = pd.read_csv('/Users/kaitlincough/Documents/data_studio/data_studio_projects/code/titanic_project_1/titanic1.csv')

# %%
df.head(200)
# Out:
#      pclass  survived               last_name  \
# 0         1         1                   Allen
# 1         1         1                 Allison
# 2         1         0                 Allison
# 3         1         0                 Allison
# 4         1         0                 Allison
# 5         1         1                Anderson
# 6         1         1                 Andrews
# 7         1         0                 Andrews
# 8         1         1                Appleton
# 9         1         0            Artagaveytia
# 10        1         0                   Astor
# 11        1         1                   Astor
# 12        1         1                  Aubart
# 13        1         1                  Barber
# 14        1         1               Barkworth
# 15        1         0                 Baumann
# 16        1         0                  Baxter
# 17        1         1                  Baxter
# 18        1         1                 Bazzani
# 19        1         0                 Beattie
# 20        1         1                Beckwith
# 21        1         1                Beckwith
# 22        1         1                    Behr
# 23        1         1                  Bidois
# 24        1         1                    Bird
# 25        1         0                Birnbaum
# 26        1         1                  Bishop
# 27        1         1                  Bishop
# 28        1         1                Bissette
# 29        1         1  Bjornstrom-Steffansson
# ..      ...       ...                     ...
# 170       1         1                   Ismay
# 171       1         0                   Jones
# 172       1         0                  Julian
# 173       1         0                 Keeping
# 174       1         0                    Kent
# 175       1         0                  Kenyon
# 176       1         1                  Kenyon
# 177       1         1                 Kimball
# 178       1         1                 Kimball
# 179       1         0                  Klaber
# 180       1         1                Kreuchen
# 181       1         1                  Leader
# 182       1         1                   LeRoy
# 183       1         1                 Lesurer
# 184       1         0                    Lewy
# 185       1         0          Lindeberg-Lind
# 186       1         1               Lindstrom
# 187       1         1                   Lines
# 188       1         1                   Lines
# 189       1         0                    Long
# 190       1         1                 Longley
# 191       1         0                  Loring
# 192       1         1                 Lurette
# 193       1         1                  Madill
# 194       1         0                 Maguire
# 195       1         1                  Maioni
# 196       1         1                Marechal
# 197       1         0                  Marvin
# 198       1         1                  Marvin
# 199       1         1                   Mayne
#
#                                             first_name     sex    age  sibsp  \
# 0                               Miss. Elisabeth Walton  female  29.00      0
# 1                                Master. Hudson Trevor    male   0.92      1
# 2                                  Miss. Helen Loraine  female   2.00      1
# 3                          Mr. Hudson Joshua Creighton    male  30.00      1
# 4               Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
# 5                                            Mr. Harry    male  48.00      0
# 6                             Miss. Kornelia Theodosia  female  63.00      1
# 7                                        Mr. Thomas Jr    male  39.00      0
# 8                  Mrs. Edward Dale (Charlotte Lamson)  female  53.00      2
# 9                                            Mr. Ramon    male  71.00      0
# 10                                     Col. John Jacob    male  47.00      1
# 11          Mrs. John Jacob (Madeleine Talmadge Force)  female  18.00      1
# 12                               Mme. Leontine Pauline  female  24.00      0
# 13                                Miss. Ellen "Nellie"  female  26.00      0
# 14                           Mr. Algernon Henry Wilson    male  80.00      0
# 15                                          Mr. John D    male    NaN      0
# 16                                    Mr. Quigg Edmond    male  24.00      0
# 17             Mrs. James (Helene DeLaudeniere Chaput)  female  50.00      0
# 18                                        Miss. Albina  female  32.00      0
# 19                                         Mr. Thomson    male  36.00      0
# 20                                 Mr. Richard Leonard    male  37.00      1
# 21              Mrs. Richard Leonard (Sallie Monypeny)  female  47.00      1
# 22                                     Mr. Karl Howell    male  26.00      0
# 23                                       Miss. Rosalie  female  42.00      0
# 24                                         Miss. Ellen  female  29.00      0
# 25                                           Mr. Jakob    male  25.00      0
# 26                                     Mr. Dickinson H    male  25.00      1
# 27                     Mrs. Dickinson H (Helen Walton)  female  19.00      1
# 28                                        Miss. Amelia  female  35.00      0
# 29                                   Mr. Mauritz Hakan    male  28.00      0
# ..                                                 ...     ...    ...    ...
# 170                                   Mr. Joseph Bruce    male  49.00      0
# 171                                Mr. Charles Cresson    male  46.00      0
# 172                                   Mr. Henry Forbes    male  50.00      0
# 173                                          Mr. Edwin    male  32.50      0
# 174                                  Mr. Edward Austin    male  58.00      0
# 175                                    Mr. Frederick R    male  41.00      1
# 176                          Mrs. Frederick R (Marion)  female    NaN      1
# 177                                Mr. Edwin Nelson Jr    male  42.00      1
# 178            Mrs. Edwin Nelson Jr (Gertrude Parsons)  female  45.00      1
# 179                                         Mr. Herman    male    NaN      0
# 180                                       Miss. Emilie  female  39.00      0
# 181                                Dr. Alice (Farnham)  female  49.00      0
# 182                                       Miss. Bertha  female  30.00      0
# 183                                      Mr. Gustave J    male  35.00      0
# 184                                        Mr. Ervin G    male    NaN      0
# 185              Mr. Erik Gustaf ("Mr Edward Lingrey")    male  42.00      0
# 186                     Mrs. Carl Johan (Sigrid Posse)  female  55.00      0
# 187                                 Miss. Mary Conover  female  16.00      0
# 188            Mrs. Ernest H (Elizabeth Lindsey James)  female  51.00      0
# 189                                   Mr. Milton Clyde    male  29.00      0
# 190                               Miss. Gretchen Fiske  female  21.00      0
# 191                                 Mr. Joseph Holland    male  30.00      0
# 192                                        Miss. Elise  female  58.00      0
# 193                          Miss. Georgette Alexandra  female  15.00      0
# 194                                    Mr. John Edward    male  30.00      0
# 195                                      Miss. Roberta  female  16.00      0
# 196                                         Mr. Pierre    male    NaN      0
# 197                                  Mr. Daniel Warner    male  19.00      1
# 198   Mrs. Daniel Warner (Mary Graham Carmichael Fa...  female  18.00      1
# 199          Mlle. Berthe Antonine ("Mrs de Villiers")  female  24.00      0
#
#      parch    ticket      fare        cabin embarked boat   body  \
# 0        0     24160  211.3375           B5        S    2    NaN
# 1        2    113781  151.5500      C22 C26        S   11    NaN
# 2        2    113781  151.5500      C22 C26        S  NaN    NaN
# 3        2    113781  151.5500      C22 C26        S  NaN  135.0
# 4        2    113781  151.5500      C22 C26        S  NaN    NaN
# 5        0     19952   26.5500          E12        S    3    NaN
# 6        0     13502   77.9583           D7        S   10    NaN
# 7        0    112050    0.0000          A36        S  NaN    NaN
# 8        0     11769   51.4792         C101        S    D    NaN
# 9        0  PC 17609   49.5042          NaN        C  NaN   22.0
# 10       0  PC 17757  227.5250      C62 C64        C  NaN  124.0
# 11       0  PC 17757  227.5250      C62 C64        C    4    NaN
# 12       0  PC 17477   69.3000          B35        C    9    NaN
# 13       0     19877   78.8500          NaN        S    6    NaN
# 14       0     27042   30.0000          A23        S    B    NaN
# 15       0  PC 17318   25.9250          NaN        S  NaN    NaN
# 16       1  PC 17558  247.5208      B58 B60        C  NaN    NaN
# 17       1  PC 17558  247.5208      B58 B60        C    6    NaN
# 18       0     11813   76.2917          D15        C    8    NaN
# 19       0     13050   75.2417           C6        C    A    NaN
# 20       1     11751   52.5542          D35        S    5    NaN
# 21       1     11751   52.5542          D35        S    5    NaN
# 22       0    111369   30.0000         C148        C    5    NaN
# 23       0  PC 17757  227.5250          NaN        C    4    NaN
# 24       0  PC 17483  221.7792          C97        S    8    NaN
# 25       0     13905   26.0000          NaN        C  NaN  148.0
# 26       0     11967   91.0792          B49        C    7    NaN
# 27       0     11967   91.0792          B49        C    7    NaN
# 28       0  PC 17760  135.6333          C99        S    8    NaN
# 29       0    110564   26.5500          C52        S    D    NaN
# ..     ...       ...       ...          ...      ...  ...    ...
# 170      0    112058    0.0000  B52 B54 B56        S    C    NaN
# 171      0       694   26.0000          NaN        S  NaN   80.0
# 172      0    113044   26.0000          E60        S  NaN    NaN
# 173      0    113503  211.5000         C132        C  NaN   45.0
# 174      0     11771   29.7000          B37        C  NaN  258.0
# 175      0     17464   51.8625          D21        S  NaN    NaN
# 176      0     17464   51.8625          D21        S    8    NaN
# 177      0     11753   52.5542          D19        S    5    NaN
# 178      0     11753   52.5542          D19        S    5    NaN
# 179      0    113028   26.5500         C124        S  NaN    NaN
# 180      0     24160  211.3375          NaN        S    2    NaN
# 181      0     17465   25.9292          D17        S    8    NaN
# 182      0  PC 17761  106.4250          NaN        C    2    NaN
# 183      0  PC 17755  512.3292         B101        C    3    NaN
# 184      0  PC 17612   27.7208          NaN        C  NaN    NaN
# 185      0     17475   26.5500          NaN        S  NaN    NaN
# 186      0    112377   27.7208          NaN        C    6    NaN
# 187      1  PC 17592   39.4000          D28        S    9    NaN
# 188      1  PC 17592   39.4000          D28        S    9    NaN
# 189      0    113501   30.0000           D6        S  NaN  126.0
# 190      0     13502   77.9583           D9        S   10    NaN
# 191      0    113801   45.5000          NaN        S  NaN    NaN
# 192      0  PC 17569  146.5208          B80        C  NaN    NaN
# 193      1     24160  211.3375           B5        S    2    NaN
# 194      0    110469   26.0000         C106        S  NaN    NaN
# 195      0    110152   86.5000          B79        S    8    NaN
# 196      0     11774   29.7000          C47        C    7    NaN
# 197      0    113773   53.1000          D30        S  NaN    NaN
# 198      0    113773   53.1000          D30        S   10    NaN
# 199      0  PC 17482   49.5042          C90        C    6    NaN
#
#                               home.dest                   home  \
# 0                          St Louis, MO           St Louis, MO
# 1       Montreal, PQ / Chesterville, ON          Montreal, PQ
# 2       Montreal, PQ / Chesterville, ON          Montreal, PQ
# 3       Montreal, PQ / Chesterville, ON          Montreal, PQ
# 4       Montreal, PQ / Chesterville, ON          Montreal, PQ
# 5                          New York, NY           New York, NY
# 6                            Hudson, NY             Hudson, NY
# 7                           Belfast, NI            Belfast, NI
# 8                   Bayside, Queens, NY    Bayside, Queens, NY
# 9                   Montevideo, Uruguay    Montevideo, Uruguay
# 10                         New York, NY           New York, NY
# 11                         New York, NY           New York, NY
# 12                        Paris, France          Paris, France
# 13                                  NaN                    NaN
# 14                        Hessle, Yorks          Hessle, Yorks
# 15                         New York, NY           New York, NY
# 16                         Montreal, PQ           Montreal, PQ
# 17                         Montreal, PQ           Montreal, PQ
# 18                                  NaN                    NaN
# 19                         Winnipeg, MN           Winnipeg, MN
# 20                         New York, NY           New York, NY
# 21                         New York, NY           New York, NY
# 22                         New York, NY           New York, NY
# 23                                  NaN                    NaN
# 24                                  NaN                    NaN
# 25                    San Francisco, CA      San Francisco, CA
# 26                         Dowagiac, MI           Dowagiac, MI
# 27                         Dowagiac, MI           Dowagiac, MI
# 28                                  NaN                    NaN
# 29   Stockholm, Sweden / Washington, DC     Stockholm, Sweden
# ..                                  ...                    ...
# 170                           Liverpool              Liverpool
# 171                      Bennington, VT         Bennington, VT
# 172                              London                 London
# 173                                 NaN                    NaN
# 174                         Buffalo, NY            Buffalo, NY
# 175             Southington / Noank, CT           Southington
# 176             Southington / Noank, CT           Southington
# 177                          Boston, MA             Boston, MA
# 178                          Boston, MA             Boston, MA
# 179                        Portland, OR           Portland, OR
# 180                                 NaN                    NaN
# 181                        New York, NY           New York, NY
# 182                                 NaN                    NaN
# 183                                 NaN                    NaN
# 184                         Chicago, IL            Chicago, IL
# 185                   Stockholm, Sweden      Stockholm, Sweden
# 186                   Stockholm, Sweden      Stockholm, Sweden
# 187                       Paris, France          Paris, France
# 188                       Paris, France          Paris, France
# 189                     Springfield, MA        Springfield, MA
# 190                          Hudson, NY             Hudson, NY
# 191               London / New York, NY                London
# 192                                 NaN                    NaN
# 193                        St Louis, MO           St Louis, MO
# 194                        Brockton, MA           Brockton, MA
# 195                                 NaN                    NaN
# 196                       Paris, France          Paris, France
# 197                        New York, NY           New York, NY
# 198                        New York, NY           New York, NY
# 199               Belgium  Montreal, PQ  Belgium  Montreal, PQ
#
#            destination Unnamed: 17
# 0                  NaN         NaN
# 1     Chesterville, ON         NaN
# 2     Chesterville, ON         NaN
# 3     Chesterville, ON         NaN
# 4     Chesterville, ON         NaN
# 5                  NaN         NaN
# 6                  NaN         NaN
# 7                  NaN         NaN
# 8                  NaN         NaN
# 9                  NaN         NaN
# 10                 NaN         NaN
# 11                 NaN         NaN
# 12                 NaN         NaN
# 13                 NaN         NaN
# 14                 NaN         NaN
# 15                 NaN         NaN
# 16                 NaN         NaN
# 17                 NaN         NaN
# 18                 NaN         NaN
# 19                 NaN         NaN
# 20                 NaN         NaN
# 21                 NaN         NaN
# 22                 NaN         NaN
# 23                 NaN         NaN
# 24                 NaN         NaN
# 25                 NaN         NaN
# 26                 NaN         NaN
# 27                 NaN         NaN
# 28                 NaN         NaN
# 29      Washington, DC         NaN
# ..                 ...         ...
# 170                NaN         NaN
# 171                NaN         NaN
# 172                NaN         NaN
# 173                NaN         NaN
# 174                NaN         NaN
# 175          Noank, CT         NaN
# 176          Noank, CT         NaN
# 177                NaN         NaN
# 178                NaN         NaN
# 179                NaN         NaN
# 180                NaN         NaN
# 181                NaN         NaN
# 182                NaN         NaN
# 183                NaN         NaN
# 184                NaN         NaN
# 185                NaN         NaN
# 186                NaN         NaN
# 187                NaN         NaN
# 188                NaN         NaN
# 189                NaN         NaN
# 190                NaN         NaN
# 191       New York, NY         NaN
# 192                NaN         NaN
# 193                NaN         NaN
# 194                NaN         NaN
# 195                NaN         NaN
# 196                NaN         NaN
# 197                NaN         NaN
# 198                NaN         NaN
# 199                NaN         NaN
#
# [200 rows x 18 columns]

# %%
df['last_name'].value_counts().head()
# Out:
# Sage         11
# Andersson    11
# Asplund       8
# Goodwin       8
# Davies        7
# Name: last_name, dtype: int64

# %%
df['first_name'].value_counts().head(10)
# Out:
#  Mr. John             13
#  Mr. William          10
#  Mr. Patrick          10
#  Mr. James             9
#  Miss. Mary            7
#  Mr. Joseph            7
#  Mr. Ivan              6
#  Miss. Kate            5
#  Mr. William Henry     5
#  Mr. Harry             5
# Name: first_name, dtype: int64

# %%
df['home'].value_counts().head(15)
# Out:
# New York, NY                            64
# Cornwall                                19
# London                                  14
# London                                  13
# Montreal, PQ                            10
# England                                  9
# Paris, France                            9
# Paris                                    9
# Philadelphia, PA                         8
# Winnipeg, MB                             8
# Wiltshire, England Niagara Falls, NY     8
# Sweden Winnipeg, MN                      7
# New York, NY                             7
# Brooklyn, NY                             7
# Belfast                                  7
# Name: home, dtype: int64

# %%
df['destination'].value_counts().head(10)
# Out:
#  Akron, OH             11
#  New York, NY           9
#  Montreal, PQ           9
#  Detroit, MI            6
#  Bernardsville, NJ      5
#  Cooperstown, NY        5
#  Hancock, MI            4
#  Winnipeg, MB           4
#  Benton Harbour, MI     4
#  Haiti                  4
# Name: destination, dtype: int64

# %%
df['home.dest'].value_counts()
# Out:
# New York, NY                                      64
# London                                            14
# Montreal, PQ                                      10
# Cornwall / Akron, OH                               9
# Paris, France                                      9
# Philadelphia, PA                                   8
# Winnipeg, MB                                       8
# Wiltshire, England Niagara Falls, NY               8
# Sweden Winnipeg, MN                                7
# Belfast                                            7
# Brooklyn, NY                                       7
# Haverford, PA / Cooperstown, NY                    5
# Ottawa, ON                                         5
# Bulgaria Chicago, IL                               5
# Rotherfield, Sussex, England Essex Co, MA          5
# Sweden Worcester, MA                               5
# Somerset / Bernardsville, NJ                       5
# Washington, DC                                     4
# Devon, England Wichita, KS                         4
# Chicago, IL                                        4
# Ireland New York, NY                               4
# St Louis, MO                                       4
# Bournmouth, England                                4
# Guntur, India / Benton Harbour, MI                 4
# Montreal, PQ / Chesterville, ON                    4
# Paris / Haiti                                      4
# Youngstown, OH                                     4
# Austria                                            4
# Ruotsinphytaa, Finland New York, NY                4
# San Francisco, CA                                  4
#                                                   ..
# Co Cork, Ireland Roxbury, MA                       1
# Victoria, BC                                       1
# Winnipeg, MN                                       1
# Provo, UT                                          1
# East Bridgewater, MA                               1
# Co Sligo, Ireland Hartford, CT                     1
# Bridgwater, Somerset, England                      1
# Gunnislake, England / Butte, MT                    1
# London / Staten Island, NY                         1
# Sarnia, ON                                         1
# Middleburg Heights, OH                             1
# Berne, Switzerland / Central City, IA              1
# England / Hartford, CT                             1
# Kilmacowen, Co Sligo, Ireland New York, NY         1
# Aughnacliff, Co Longford, Ireland New York, NY     1
# Stockholm, Sweden / Washington, DC                 1
# London / Winnipeg, MB                              1
# Hartford, Huntingdonshire                          1
# Brookline, MA                                      1
# Medeltorp, Sweden Chicago, IL                      1
# Oslo, Norway Bayonne, NJ                           1
# Salo, Finland Astoria, OR                          1
# Myren, Sweden New York, NY                         1
# Bath, England / Massachusetts                      1
# Karberg, Sweden Jerome Junction, AZ                1
# London Skanteales, NY                              1
# Norrlot, Sweden Chicago, IL                        1
# Waukegan, Chicago, IL                              1
# Southampton / New York, NY                         1
# Halesworth, England                                1
# Name: home.dest, Length: 369, dtype: int64

# %%
df.shape
# Out:
# (1309, 17)

# %% [markdown]
# ### An important note: there are 1309 passengers in this dataset. Numbers vary as to how many passengers were aboard, but it was somewhere in the area of 2,220 or so, with 702 survivors. That's over 1,500 people who perished. So the data is incomplete and should be regarded as such.
# (This didn't actually occur to me until I was pretty deep into working with the dataset--but it's a good lesson to take into account the data's limitations before diving in.)

# %% [markdown]
# We can start with some preliminary analysis, just to get an idea of what we're working with.

# %%
#what's the average fare in each class?
df.groupby('pclass')['fare'].mean()
# Out:
# pclass
# 1    87.508992
# 2    21.179196
# 3    13.302889
# Name: fare, dtype: float64

# %%
#filter the data frame for survivors
survivors = df[df["survived"] == 1]
survivors.head()
# Out:
#    pclass  survived first_name                             last_name     sex  \
# 0       1         1      Allen                Miss. Elisabeth Walton  female
# 1       1         1    Allison                 Master. Hudson Trevor    male
# 5       1         1   Anderson                             Mr. Harry    male
# 6       1         1    Andrews              Miss. Kornelia Theodosia  female
# 8       1         1   Appleton   Mrs. Edward Dale (Charlotte Lamson)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat  body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2   NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11   NaN
# 5  48.00      0      0   19952   26.5500      E12        S    3   NaN
# 6  63.00      1      0   13502   77.9583       D7        S   10   NaN
# 8  53.00      2      0   11769   51.4792     C101        S    D   NaN
#
#                   home        destination Unnamed: 16
# 0         St Louis, MO                NaN         NaN
# 1        Montreal, PQ    Chesterville, ON         NaN
# 5         New York, NY                NaN         NaN
# 6           Hudson, NY                NaN         NaN
# 8  Bayside, Queens, NY                NaN         NaN

# %%
survivors['last_name'].value_counts()
# Out:
#  Miss. Bertha                                              4
#  Miss. Mary                                                3
#  Miss. Anna Sofia                                          3
#  Miss. Kate                                                3
#  Miss. Anna                                                3
#  Miss. Ellen "Nellie"                                      3
#  Mr. Edward                                                2
#  Miss. Alice                                               2
#  Miss. Katherine "Katie"                                   2
#  Miss. Ellen                                               2
#  Miss. Elizabeth                                           2
#  Mrs. William Baird (Alice Munger)                         1
#  Mrs. Thomas Henry (Mary E Finck)                          1
#  Miss. Anna Kristine                                       1
#  Mr. George ("George Arthur Brayton")                      1
#  Mlle. Emma                                                1
#  Mr. Harry ("Mr E Haven")                                  1
#  Mrs. (Amelia Milley)                                      1
#  Miss. Sara Rebecca                                        1
#  Mr. Johan Charles                                         1
#  Master. Richard F                                         1
#  Mr. Victor Francis                                        1
#  Mr. Juha                                                  1
#  Mrs. Leopold (Mathilde Francoise Pede)                    1
#  Miss. Bridget Delia                                       1
#  Master. Artur Karl                                        1
#  Mrs. Mariana ("Miriam")                                   1
#  Miss. Rosalie                                             1
#  Miss. Hedwig Margaritha                                   1
#  Dr. Alice (Farnham)                                       1
#                                                           ..
#  Mr. Carl                                                  1
#  Mr. Oskar Leander                                         1
#  Miss. Maude                                               1
#  Mr. Charles                                               1
#  Mrs. Charles V (Ada Maria Winfield)                       1
#  Mrs. Henry Arthur Jr (Eleanor Genevieve Fosdick)          1
#  Mr. Hugh                                                  1
#  Miss. Sarah A                                             1
#  Mrs. (Lutie Davis)                                        1
#  Miss. Bertha E                                            1
#  Mr. Gilbert Milligan Jr                                   1
#  Mr. Emilio Ilario Giuseppe                                1
#  Miss. Edith Eileen                                        1
#  Miss. Ruth Elizabeth                                      1
#  Mr. Edward Pennington                                     1
#  Miss. Virginia Ethel                                      1
#  Mr. Daniel                                                1
#  Miss. Lucile Polk                                         1
#  Mr. Eugene Patrick                                        1
#  Master. Andre                                             1
#  Miss. Nellie                                              1
#  Miss. Hanora "Nora"                                       1
#  Mr. Lawrence                                              1
#  Mr. David                                                 1
#  Mrs. Daniel Warner (Mary Graham Carmichael Farquarson)    1
#  Mr. Joseph                                                1
#  Miss. Madeleine                                           1
#  Mrs. Hjalmar (Agnes Charlotta Bengtsson)                  1
#  Mrs. William Thompson (Edith Junkins)                     1
#  Master. Frank John William "Frankie"                      1
# Name: last_name, Length: 482, dtype: int64

# %%
#the average fare paid by people 
#who survived
survivors['fare'].describe()
# Out:
# count    500.000000
# mean      49.361184
# std       68.648795
# min        0.000000
# 25%       11.214600
# 50%       26.000000
# 75%       57.750000
# max      512.329200
# Name: fare, dtype: float64

# %%
#what percentage of people survived in each passenger class?

survivors['pclass'].value_counts()/1309 * 100
# Out:
# 1    15.278839
# 3    13.827349
# 2     9.090909
# Name: pclass, dtype: float64

# %%
#how many survivors were there from each class?
ax = survivors['pclass'].sort_values(ascending=True).value_counts().plot(kind='bar', figsize=(10,5))
ax.set_ylabel('number of survivors')
ax.set_xlabel('passenger class')

# %% [markdown]
# ## Let's examine things based on sex/gender

# %%
women = df[df['sex'] == 'female']
women.head()
# Out:
#    pclass  survived last_name                               first_name  \
# 0       1         1     Allen                   Miss. Elisabeth Walton
# 2       1         0   Allison                      Miss. Helen Loraine
# 4       1         0   Allison   Mrs. Hudson J C (Bessie Waldo Daniels)
# 6       1         1   Andrews                 Miss. Kornelia Theodosia
# 8       1         1  Appleton      Mrs. Edward Dale (Charlotte Lamson)
#
#       sex   age  sibsp  parch  ticket      fare    cabin embarked boat  body  \
# 0  female  29.0      0      0   24160  211.3375       B5        S    2   NaN
# 2  female   2.0      1      2  113781  151.5500  C22 C26        S  NaN   NaN
# 4  female  25.0      1      2  113781  151.5500  C22 C26        S  NaN   NaN
# 6  female  63.0      1      0   13502   77.9583       D7        S   10   NaN
# 8  female  53.0      2      0   11769   51.4792     C101        S    D   NaN
#
#                   home        destination Unnamed: 16
# 0         St Louis, MO                NaN         NaN
# 2        Montreal, PQ    Chesterville, ON         NaN
# 4        Montreal, PQ    Chesterville, ON         NaN
# 6           Hudson, NY                NaN         NaN
# 8  Bayside, Queens, NY                NaN         NaN

# %%
women['first_name'].value_counts().head(10)
# Out:
#  Miss. Mary              7
#  Miss. Kate              5
#  Miss. Bertha            4
#  Miss. Anna Sofia        3
#  Miss. Ellen "Nellie"    3
#  Miss. Anna              3
#  Miss. Elizabeth         3
#  Miss. Bridget           2
#  Miss. Hanora "Nora"     2
#  Miss. Katherine         2
# Name: first_name, dtype: int64

# %%
women.shape
# Out:
# (466, 17)

# %%
women['pclass'].value_counts()

# %%
#what percentage of women survived?
women['survived'].value_counts() /466 * 100

# %%
33

# %%
female_survivors = women[women['survived'] == 1]
female_survivors.head()

# %%
female_survivors['fare'].describe()

# %%
female_survivors['pclass'].value_counts().plot(kind='bar')

# %%
men = df[df['sex'] == 'male']
men.head()
# Out:
#    pclass  survived     last_name                    first_name   sex    age  \
# 1       1         1       Allison         Master. Hudson Trevor  male   0.92
# 3       1         0       Allison   Mr. Hudson Joshua Creighton  male  30.00
# 5       1         1      Anderson                     Mr. Harry  male  48.00
# 7       1         0       Andrews                 Mr. Thomas Jr  male  39.00
# 9       1         0  Artagaveytia                     Mr. Ramon  male  71.00
#
#    sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 1      1      2    113781  151.5500  C22 C26        S   11    NaN
# 3      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 5      0      0     19952   26.5500      E12        S    3    NaN
# 7      0      0    112050    0.0000      A36        S  NaN    NaN
# 9      0      0  PC 17609   49.5042      NaN        C  NaN   22.0
#
#                   home        destination Unnamed: 16
# 1        Montreal, PQ    Chesterville, ON         NaN
# 3        Montreal, PQ    Chesterville, ON         NaN
# 5         New York, NY                NaN         NaN
# 7          Belfast, NI                NaN         NaN
# 9  Montevideo, Uruguay                NaN         NaN

# %%
men['first_name'].value_counts().head()
# Out:
#  Mr. John       13
#  Mr. Patrick    10
#  Mr. William    10
#  Mr. James       9
#  Mr. Joseph      7
# Name: first_name, dtype: int64

# %%
men.shape

# %%
men['pclass'].value_counts()

# %%
men['survived'].value_counts() / 843 * 100

# %%
#let's look at just the survivors
male_survivors = men[men['survived'] == 1]
male_survivors.head()

# %%
male_survivors['fare'].describe()

# %%
male_survivors['pclass'].value_counts().plot(kind='bar')

# %%
#groupby sex
df.groupby('sex')['survived'].count()

# %%
#how many men? women?
df['sex'].value_counts()

# %%
ax = df['sex'].value_counts().plot(kind='bar', title='Passengers aboard the Titanic')

ax.set_ylabel=('number of passengers')



# ax = kids.groupby(['parch']).sum().plot(kind='bar', y='survived', figsize=(20,10), title='Children Who Survived the Titanic Disaster')
# ax.set_xlabel('Number of adults a child was traveling with')
# ax.set_ylabel('Number of surviving children')

# %% [markdown]
# ### What was the average age of passengers? The oldest? The youngest?

# %%
#what was the average age of passengers?
df['age'].describe()

# %%
#the average age of survivors
survivors['age'].describe()

# %% [markdown]
# ### The average fare? The most expensive?

# %%
#average fare price? max?
df['fare'].describe()

# %%
#avg fare paid by survivors
survivors['fare'].describe()

# %% [markdown]
# ### The cheapest is 0 because there were crew members who did not pay for passage.

# %% [markdown]
# ### How many passengers were traveling in 3rd class? 1st class?

# %%
ax = df['pclass'].value_counts().plot(kind='bar', title='Passengers aboard the Titanic, by class')
ax.set_xlabel('passenger class')
ax.set_ylabel('number of passengers')

# %% [markdown]
# ### What percentage of passengers survived?

# %%
#so divide the number of surviving passengers (sum of survived) by 
#the total number of passengers and subtract that number
#from 100

df['survived'].sum() / 1309 * 100

# %% [markdown]
# Where were people coming from/going to?

# %%
df['home.dest'].value_counts().head(20)

# %%
embarked = df.groupby('embarked')
embarked.head()

# %% [markdown]
# Were you more likely to survive if you embarked in a certain place?

# %%
df[df['embarked'] == 'C'].fare.describe()

# %%
df[df['embarked'] == 'S'].fare.describe()

# %%
df[df['embarked'] == 'Q'].fare.describe()

# %%
embarked['survived'].value_counts()

# %%
embarked['survived'].describe()

# %%
#Cherbourg
print(150/270 * 100, '% of people who embarked in Cherbourg survived')

# %%
#Queenstown
print(44/123 * 100, '% of people who embarked in Queenstown survived')

# %%
#Southampton
print(304/914 * 100, '% of people who embarked in Southampton survived')

# %% [markdown]
# ### How many children were traveling without a parent?

# %%
#make a new dataset with just children (under 18)
kids = df[df['age'] < 18]
kids.head()

# %%
kids.shape

# %%
#all the children traveling without a parent
kids[kids['parch'] == 0].shape

# %%
#so there were 154 children on board and 42 were 
#traveling without a parent
42/154 *100

# %% [markdown]
# ### So there are 42 children in this dataset traveling without a parent (likely with a nanny). How many of them survived?

# %%
kids[(kids['parch'] == 0) & (kids['survived'] == 1)].shape

# %%
#the number of children who survived based on how many 
#people they were traveling with
#I know this is totally morbid.

ax = kids.groupby(['parch']).sum().plot(kind='bar', y='survived', figsize=(20,10), title='Children Who Survived the Titanic Disaster')
ax.set_xlabel('Number of adults a child was traveling with')
ax.set_ylabel('Number of surviving children')

# %% [markdown]
# ### Were you more likely to survive if you were a man or a woman?

# %%
#what percentage of female passenger perished? of male passengers?
females = df[(df['sex'] == 'female')]
females.head()

# %%
females['survived'].sum() / 1309 * 100

# %%
#what percentage of female passenger perished? of male passengers?
male = df[(df['sex'] == 'male')]

# %%
male['survived'].sum() / 1309 * 100

# %% [markdown]
# So you were more than twice as likely to survive the sinking if you were a female.
#
#
#
# ## Let's switch gears and think about the fare prices. The original question I set out to answer was: if you paid a higher fare were you more likely to survive the sinking?

# %%
#let's look at all of the different fares and how many people paid 
#each fare value. there are lots of random ones.
df['fare'].value_counts().sort_values(ascending=False).head()

# %%
ax = df['fare'].plot(figsize=(20,10), kind='hist', bins=100, title='Fares paid for passage on the Titanic')
ax.set_xlabel('fare in british pounds')
ax.set_ylabel('number of tickets sold')

# %%
# df['fare'].hist(bins=50)

# %% [markdown]
# ### Let's group by the fare price. Were you more likely to survive if you paid more for a ticket?

# %%
#what (column to group by), [what column you want info about], .what kind of info you want()
#let's look at this. groupby fare and get information on the survived column

fare_grouped = df.groupby('fare')['survived'].sum()
fare_grouped.head()

# %%
#turn this series into a dataframe 

fare_grouped = fare_grouped.to_frame('fare_grouped')

# %%
fare_grouped.head()

# %%
#rename the columns immediately because otherwise
#it's confusing

fare_grouped.rename(columns={'fare_grouped':'number_survivors'}, inplace=True)
fare_grouped.head()

# %%
#PLOT NUMBER OF PEOPLE WHO DIED BASED ON THE TICKET PRICE

#ticket price on y axis
# x axis is number of people who died
#maybe plot as a line graph

# %%
fare_grouped.head()

# %%
# def fare(c):
#     if c['rounded_fare'] < 50:
#         return 50
#     elif c['rounded_fare'] < 100:
#         return 100
#     elif c['rounded_fare'] < 200:
#         return 200
#     elif c['rounded_fare'] < 300:
#         return 300
#     elif c['rounded_fare'] < 400:
#         return 400
#     elif c['rounded_fare'] < 500:
#         return 500
#     else:
#         return 'other'
    
# fare_grouped['fare_categories'] = fare_grouped.apply(fare, axis=1)
# fare_grouped.head(400)

# %%
# ax = fare_grouped.plot(kind='bar',
#                   x='fare_categories', 
#                   y='number_survivors', 
#                   figsize=(20,10)
#                   )
# ax.set_label = 'fare'

# %%
#create a new column with the number of tickets purchased
#based on the value counts for the fare column in the OG df

fare_grouped['number_tickets_purchased'] = df['fare'].value_counts()
fare_grouped.head()

# %%
fare_grouped.reset_index(inplace=True)

# %%
#let's add a column with rounded fares so they 
#make a cleaner graph
fare_grouped['rounded_fare'] = fare_grouped['fare'].round() 
fare_grouped.head()

# %%
#create a new column with the survival rate
#by dividing the # of survivors
#by the # of people who purchased a ticket at 
#that fare survivors / number_tickets_purchased

fare_grouped['survival_%_rate'] = (fare_grouped['number_survivors']/fare_grouped['number_tickets_purchased']) * 100

# %%
fare_grouped['embarked'] = df['embarked']

# %%
df.head()

# %%
fare_grouped.head(30)

# %%
# fare_grouped.plot(x='survival_%_rate', y='fare', kind='barh', figsize=(20,20))

# %%
#in a misguided attempt to color the 
#scatterplot dots according to number of 
#tickets purchased I added a color column
# def color(c):
#     if c['number_tickets_purchased'] < 5:
#         return 'red'
#     elif c['number_tickets_purchased'] < 10:
#         return 'orange'
#     elif c['number_tickets_purchased'] < 15:
#         return 'yellow'
#     elif c['number_tickets_purchased'] < 20:
#         return 'green'
#     elif c['number_tickets_purchased'] < 30:
#         return 'blue'
#     elif c['number_tickets_purchased'] < 40:
#         return 'purple'
#     else:
#         return 'white'
    
# fare_grouped['color'] = fare_grouped.apply(color, axis=1)
# fare_grouped.head(400)

# %%
sizes = fare_grouped.apply(lambda row: row['number_tickets_purchased'] * 100, axis=1)


#multiply by 100 just to make the dots visible.

#this turns the circle size into the number of tickets purchased * 100


ax = fare_grouped.plot(x='survival_%_rate', 
                  y='fare', 
                  kind='scatter', 
                  figsize=(20,20), 
                  alpha=0.5,
                  s=sizes)



ax.set_xlabel('percentage likelihood of survival', fontsize=18)
ax.set_ylabel('fare in british pounds', fontsize=18)
plt.savefig('survival.pdf')

# %% [markdown]
# ### Here's some interesting info on fare prices and how they were calculated for this dataset:
# http://www.statisticalconsultants.co.nz/blog/titanic-fare-data.html
